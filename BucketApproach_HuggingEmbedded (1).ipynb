# %%
import pandas as pd
from transformers import AutoTokenizer, GPT2LMHeadModel, pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from collections import defaultdict

# %%
# !pip install datasets
# !pip install langchain
# !pip install ctransformers
# !pip install nltk
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1
# Collecting langchain
#   Downloading langchain-0.1.12-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.28 (from langchain)
#   Downloading langchain_community-0.0.28-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 39.1 MB/s eta 0:00:00
# Collecting langchain-core<0.2.0,>=0.1.31 (from langchain)
#   Downloading langchain_core-0.1.32-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 22.1 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.27-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.31->langchain) (3.7.1)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.31->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.0 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain) (1.2.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.12 langchain-community-0.0.28 langchain-core-0.1.32 langchain-text-splitters-0.0.1 langsmith-0.1.27 marshmallow-3.21.1 mypy-extensions-1.0.0 orjson-3.9.15 packaging-23.2 typing-inspect-0.9.0
# Collecting ctransformers
#   Downloading ctransformers-0.2.27-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from ctransformers) (0.20.3)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2024.2.2)
# Installing collected packages: ctransformers
# Successfully installed ctransformers-0.2.27
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
from datasets import load_dataset
dataset = load_dataset("hugginglearners/netflix-shows", split="train")
df = pd.DataFrame(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
df = pd.DataFrame(dataset)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                                  None           None
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                               None           None
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
# Feature extraction
vectorizer = TfidfVectorizer(max_features=1000)
X_tfidf = vectorizer.fit_transform(df['description'])

# %%
# Clustering with KMeans
num_clusters = 15
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['cluster_label'] = kmeans.fit_predict(X_tfidf)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df[['description', 'cluster_label']], df['listed_in'], test_size=0.2, random_state=42)

# Enhance feature space with cluster labels
X_train_tfidf = vectorizer.transform(X_train['description'])
X_test_tfidf = vectorizer.transform(X_test['description'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Method 1: Generating decriptions using tokenization and then determining whether they fit the model
from transformers import AutoTokenizer, GPT2LMHeadModel, pipeline
from transformers import GPT2Tokenizer

# Logistic Regression to refine clustering
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_tfidf, y_train)
df['predicted_genre'] = clf.predict(vectorizer.transform(df['description']))

# Generate descriptions using GPT-2
model_name = "gpt2-medium"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
#Method 2: Generating buckets, printing decriptions, then finding accuracies of all the buckets
# Create genre buckets
genre_lists = df['listed_in'].str.split(", ")
all_genres = set()
for genres in genre_lists:
    all_genres.update(genres)
bucket_queue = {genre: [] for genre in all_genres}

# %%
def generate_descriptions(genres, num_descriptions=3):
    model_name = "gpt2"
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    model = GPT2LMHeadModel.from_pretrained(model_name)
    generator = pipeline('text-generation', model=model, tokenizer=tokenizer)

    genre_descriptions = {}
    for genre in genres:
        prompt = f"The genre is {genre}. Describe a typical {genre} TV show: "
        descriptions = generator(prompt, max_length=50, num_return_sequences=num_descriptions)
        genre_descriptions[genre] = [desc['generated_text'] for desc in descriptions]

    return genre_descriptions

genre_descriptions = generate_descriptions(all_genres)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
def print_genre_descriptions(genre_descriptions):
    print("Generated Descriptions by Genre:\n")
    for genre, descriptions in genre_descriptions.items():
        print(f"Genre: {genre}")
        for i, description in enumerate(descriptions, start=1):
            print(f"  Description {i}: {description.strip()}")
        print("\n")
print_genre_descriptions(genre_descriptions)
# Out:
# Generated Descriptions by Genre:
#
# Genre: TV Dramas
#   Description 1: The genre is TV Dramas. Describe a typical TV Dramas TV show:  (a) A group of very young teenagers that come together in a city that has seen an awful lot of riots.  (b) A mob
#   Description 2: The genre is TV Dramas. Describe a typical TV Dramas TV show:  Most of its shows are written by people who've never watched a TV show before, so they're familiar with a lot of tropes from the original shows (
#   Description 3: The genre is TV Dramas. Describe a typical TV Dramas TV show:  episode 1 (9 episodes).  2 (12 episodes) In-House TV Episode (9 episodes)
# Video Games:  P
#
#
# Genre: Crime TV Shows
#   Description 1: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  You'll also appreciate the different genres including  Crime   TV,  Casual TV,  Arrested Development,  Action,  TV Originals,
#   Description 2: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  Criminal Minds, Crime Action-Adventure, Crime Investigation/Crimey Adventure, Cyber Punk, Criminology 101; also  Breaking Bad:
#   Description 3: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  
#
# ※    3-D 
#
#
# Genre: TV Comedies
#   Description 1: The genre is TV Comedies. Describe a typical TV Comedies TV show:  (1) a show that has lots of random and/or random twists from each season
# (2) one that is based around a person's life
#   Description 2: The genre is TV Comedies. Describe a typical TV Comedies TV show: __________________________
#
# Miles Teller (2011-14): "Lonely Boy"
#
# Bob Saget (2006-15): "Wish
#   Description 3: The genre is TV Comedies. Describe a typical TV Comedies TV show: Â
#
# "I'm very surprised that you've become a part of that. It had to happen first. I know that you might not be an avid
#
#
# Genre: TV Action & Adventure
#   Description 1: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  What you are doing is writing the story for a television show and you want it to have a great setting, a strong character and a great story
#   Description 2: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  How often is this TV Action & Adventure TV Show? What genre of TV television is on your list? A typical TV Action & Adventure episode:
#   Description 3: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  1. The first season is a little different than the previous few;  2. The show had all of its characters coming off an arc
#
#
# Genre: Teen TV Shows
#   Description 1: The genre is Teen TV Shows. Describe a typical Teen TV Shows TV show:  In episode 11 we get started on a character who is introduced as an all women show in episode 10. We then go on a series of adventures, some
#   Description 2: The genre is Teen TV Shows. Describe a typical Teen TV Shows TV show:  A cartoon character with an open mouth in the middle and a pretty face. A common character in this genre is: Teen TV Shows Teen TV Shows Teen TV
#   Description 3: The genre is Teen TV Shows. Describe a typical Teen TV Shows TV show:  The character A.G.A. is a teenager in the 19th Century whose adventures in the dark times of modern times led her to the location where
#
#
# Genre: Docuseries
#   Description 1: The genre is Docuseries. Describe a typical Docuseries TV show:  An episode with a character (who will likely end up on the cover) wearing his or her own clothes, drinking alcohol, and drinking at a party (
#   Description 2: The genre is Docuseries. Describe a typical Docuseries TV show:  The character can look very cool, look like a dude in a movie, be very likable and show off his character traits.
# As we start collecting
#   Description 3: The genre is Docuseries. Describe a typical Docuseries TV show:  Dudley Dandy  or Mr. Gumpus  (that was one title for most of Docuseries's run as TV shows
#
#
# Genre: International TV Shows
#   Description 1: The genre is International TV Shows. Describe a typical International TV Shows TV show:  - The  'Shakespeare of the TV Show: 'The New York Times' - - The 'Shakespeare of the TV Show: 'The New
#   Description 2: The genre is International TV Shows. Describe a typical International TV Shows TV show: ???? -???????
#
# Related
#   Description 3: The genre is International TV Shows. Describe a typical International TV Shows TV show: *************** US Show (3:00-7:00pm): ********** USA Sports Show (3:00-9:00pm): ___
#
#
# Genre: Romantic Movies
#   Description 1: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  We are looking for:  A young person getting ready for an adventure.  They see their father or grandfather.  They see a movie scene.
#   Description 2: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  If you are playing by the rules of the show, pick three characters;  then it will be a show that is on "rules.txt", so when
#   Description 3: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  Cast, characters, episodes, events, settings, story, or a combination of all three to describe the Romantic series
# I'll use a movie trope with one,
#
#
# Genre: Sci-Fi & Fantasy
#   Description 1: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show: ------------- RON SONG - -------------- RON DANIELS - -------------- PEPE - ------------ TEEN TITANS -
#   Description 2: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show:  "As the "good guys" of the show, the players must confront a world rife with dark forces, and a few choices are
#   Description 3: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show:  Game or Adventure.  A typical Sci-Fi TV show involves a high school science (or high school romance).  How
#
#
# Genre: Horror Movies
#   Description 1: The genre is Horror Movies. Describe a typical Horror Movies TV show:  The movie is one of a couple comedies between a male and female character, and it has a sexual relationship between a female actor and a male character. This gives
#   Description 2: The genre is Horror Movies. Describe a typical Horror Movies TV show:  What would they look like? What if he really did kill you?
# What if he did kill you? What if one person did all of it, that person
#   Description 3: The genre is Horror Movies. Describe a typical Horror Movies TV show:  an evil-but-kind-of-human-sliding plot, a great twist in a story or two, the like of "The House of Blood."
#
#
# Genre: International Movies
#   Description 1: The genre is International Movies. Describe a typical International Movies TV show: ______________________________________ The plot: ______________________________________ "As many good young guys go off on different trips as I do, and then a little thing of beauty slips over them in
#   Description 2: The genre is International Movies. Describe a typical International Movies TV show: ******** The show is called World Premiere. The episode starts with a series, so if you're watching a TV show, make sure that you've been told to take all
#   Description 3: The genre is International Movies. Describe a typical International Movies TV show: ..................................................................................................................................... It is usually a western in character but mostly a Western in design.............................................................The average person probably likes a western when it has a storyline and
#
#
# Genre: Kids' TV
#   Description 1: The genre is Kids' TV. Describe a typical Kids' TV TV show:  1.)  Produces a typical series  2.)  Produces a series in which a guest character dies on an episode of a network show
#   Description 2: The genre is Kids' TV. Describe a typical Kids' TV TV show:  What is the most common format, or sub-genre, and how does it work?  In this piece, I'll provide a quick and easy guide
#   Description 3: The genre is Kids' TV. Describe a typical Kids' TV TV show:  "The show premiered to a wide audience and drew millions watching to see how we used this material."  "We created what was a very traditional, non
#
#
# Genre: Anime Features
#   Description 1: The genre is Anime Features. Describe a typical Anime Features TV show: 今国曇画のサイト (Season 1) - 下本口雕 (Season 2) - 且
#   Description 2: The genre is Anime Features. Describe a typical Anime Features TV show: 『Frozen』, 『Star Wars』, 『Star Wars: Jedi Knight』, 『Toy Story』 (like Star Wars: The Force Awakens),
#   Description 3: The genre is Anime Features. Describe a typical Anime Features TV show:  In an Anime Feature TV show, one of the main characters (you like the series) is in a different person in other anime. The series has been going on
#
#
# Genre: Sports Movies
#   Description 1: The genre is Sports Movies. Describe a typical Sports Movies TV show:  A sports talk show based on a sports movie.  The topic of a Sports Movie is something that tends to go around the Internet:  The sports or
#   Description 2: The genre is Sports Movies. Describe a typical Sports Movies TV show:  " "I think sports dramas are so far overrated in terms of popularity and it's a real treat. So, if your TV show has to be on
#   Description 3: The genre is Sports Movies. Describe a typical Sports Movies TV show:  "The TV will show an episode of the sports movie that involves a lot of athletes, the show then includes sports from the past. This is how you find the
#
#
# Genre: LGBTQ Movies
#   Description 1: The genre is LGBTQ Movies. Describe a typical LGBTQ Movies TV show:  "You don't always win. Sometimes you are left out with a very minor, even marginal or small flaw. I don't think the problem is simply that those
#   Description 2: The genre is LGBTQ Movies. Describe a typical LGBTQ Movies TV show:  Fictional Black or Latino TV show (not TV series, since it has a different genre of content).  In other words,  say the show
#   Description 3: The genre is LGBTQ Movies. Describe a typical LGBTQ Movies TV show:  The most basic premise involves a bunch of transgender people who just want to get to the bathroom. It will be fun, it will require no special action and a lot
#
#
# Genre: Stand-Up Comedy & Talk Shows
#   Description 1: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:  Here is the list of popular Stand-Up Comedy & Talk Shows shows in the US.   A show may be
#   Description 2: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:  How you put it together (that includes having it on cable or a satellite TV network) with a big budget,
#   Description 3: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:   .     
#
#
# Genre: Music & Musicals
#   Description 1: The genre is Music & Musicals. Describe a typical Music & Musicals TV show:  "As a former musician, I have been involved primarily in music and drama shows as well"      (http://musicsand
#   Description 2: The genre is Music & Musicals. Describe a typical Music & Musicals TV show:  Suit your friend through the show to find out if that character is good or bad as it becomes more or less defined.  Most shows
#   Description 3: The genre is Music & Musicals. Describe a typical Music & Musicals TV show:  "The program is typically scripted by some celebrity, usually for financial gain, and the show has a cast of characters. It has a cast of
#
#
# Genre: Anime Series
#   Description 1: The genre is Anime Series. Describe a typical Anime Series TV show:  - How many episodes will you show? One, two, three, or four.
# -    We also have an 8-part series based on the TV
#   Description 2: The genre is Anime Series. Describe a typical Anime Series TV show:  an arc between a teenage boy and his friends to a meeting of one-man robots.  Both men are forced to choose one character and then some, using
#   Description 3: The genre is Anime Series. Describe a typical Anime Series TV show:  The TV series starts the anime series and is very long. A lot of time goes into building up the cast, writing, voice acting, acting and writing.
#
#
# Genre: Action & Adventure
#   Description 1: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  The action-heavy shows use a variety of tactics from explosions, bombs, and bullets and end their run with the most dramatic fight scenes, as well as
#   Description 2: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  a movie, television show, or a web show. Be concise.
# Take your time with every word you say and figure out your own tone and meaning
#   Description 3: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  I'm playing "Wet Gunner," and I try to fire my shotgun for extra effect. When I think of a movie, I often think of
#
#
# Genre: Reality TV
#   Description 1: The genre is Reality TV. Describe a typical Reality TV TV show:  Do you have any kind of show that you don't relate to?  Do you watch it often?  Who cares who your favorite network is?
#   Description 2: The genre is Reality TV. Describe a typical Reality TV TV show:  - a "live" panel, like a reality show, with a large room with a panel and a small studio.  As such, we recommend finding the
#   Description 3: The genre is Reality TV. Describe a typical Reality TV TV show:  "The characters live in real homes and spend hours at the television or online. This is often referred to as'reality TV.'"  I have heard this in
#
#
# Genre: Comedies
#   Description 1: The genre is Comedies. Describe a typical Comedies TV show:  "I usually don't pick a favorite scene and just write 'you got some good jokes, I like it', since that's one line I feel like being a
#   Description 2: The genre is Comedies. Describe a typical Comedies TV show:  "It really had a nice vibe that wasn't too cliche or boring but kind of funny. It had this big 'F' or 'G' wording
#   Description 3: The genre is Comedies. Describe a typical Comedies TV show: _____, ______, and ______. It would not be complete without also mentioning "The New York Times," one of the oldest and very popular comedy news networks in New York
#
#
# Genre: Classic & Cult TV
#   Description 1: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show:  "A TV that shows the world that "Mummy" is a myth that is just as prevalent. As long as the Myth, Myth,
#   Description 2: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show:  How did you make The Show, the show that turned your entire TV career into a joke, and why did you choose to do it?
#   Description 3: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show: ~~ 1) I was in the US and watched American Horror Story when my parents gave up their lives in order to find some jobs, which meant I
#
#
# Genre: Classic Movies
#   Description 1: The genre is Classic Movies. Describe a typical Classic Movies TV show:  In the first half, one or maybe more of the characters is a character, from The Avengers to X-Men Origins: Wolverine, etc. If that character is
#   Description 2: The genre is Classic Movies. Describe a typical Classic Movies TV show:  the show takes place in the '80s with an amazing cast, and everything is always the same season - a few new character actors fall in and out over the
#   Description 3: The genre is Classic Movies. Describe a typical Classic Movies TV show:  (a) the show is based on the novels of Robert Heinlein (e.g. "The Hitchhiker's Guide to the Galaxy", etc.) and
#
#
# Genre: Stand-Up Comedy
#   Description 1: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show:  a comedy with comedic moments of a certain order/class, followed by a dramatic theme.  We have two parts.  In a
#   Description 2: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show:  "I know that for the last four years, I have been listening to this type of talk radio show and I have watched it for the last
#   Description 3: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show: ????
#
# If you're playing this Game of Thrones, go tell your friends you're doing stand-up after reading the above articles.
#
#
# Genre: Korean TV Shows
#   Description 1: The genre is Korean TV Shows. Describe a typical Korean TV Shows TV show: 他以投黄
#
# 는 정컩주다. 쨴니
#   Description 2: The genre is Korean TV Shows. Describe a typical Korean TV Shows TV show: 하뤌로다하어 (This is what I like about it. It is also very romantic) �
#   Description 3: The genre is Korean TV Shows. Describe a typical Korean TV Shows TV show: 클라이 포려터ꖜ 합니다. You can find
#
#
# Genre: Spanish-Language TV Shows
#   Description 1: The genre is Spanish-Language TV Shows. Describe a typical Spanish-Language TV Shows TV show: ˈɪtʌɣn ˈtʌnʋnt
#
# Latin American
#
# American
#
# Community
#   Description 2: The genre is Spanish-Language TV Shows. Describe a typical Spanish-Language TV Shows TV show:  a small group of students, typically Spanish-speaking, who are either studying for a class of Masters or for a Bachelor's or have
#   Description 3: The genre is Spanish-Language TV Shows. Describe a typical Spanish-Language TV Shows TV show: --------------- The American Southwest in the 1970s and 1980s. --------------- USA in the early '70s/early '80s.
#
#
# Genre: Independent Movies
#   Description 1: The genre is Independent Movies. Describe a typical Independent Movies TV show:  In an episodic fashion, it can be found around the UK or USA on any of the major cable TV networks. The main point to understand about the movie I
#   Description 2: The genre is Independent Movies. Describe a typical Independent Movies TV show:  -  In a comedy sketch, the characters say a few funny words and have to be reminded that there are "no rules", "no rules", no rules.
#   Description 3: The genre is Independent Movies. Describe a typical Independent Movies TV show:  What can the audience see?  What does the audience feel?  Does the audience believe what they are seeing?  What is in the character?
#
#
# Genre: TV Horror
#   Description 1: The genre is TV Horror. Describe a typical TV Horror TV show:  "We have that kind of audience, we put ourselves forward as characters — they're a bunch of people, if you'll pardon the pun — and the show is
#   Description 2: The genre is TV Horror. Describe a typical TV Horror TV show:  What we know is it's based on a very large, well-known name that is written in a certain alphabet. We may be looking at an episode of a
#   Description 3: The genre is TV Horror. Describe a typical TV Horror TV show:  Do you want it to be more in the vein of classic horror? Or more in that vein? And what does that show look like? In the original show,
#
#
# Genre: Dramas
#   Description 1: The genre is Dramas. Describe a typical Dramas TV show: ~~ Comedy ~~ The TV Show: ~~~~~~~~~~~~~~~~~~~~~~~~~~- ~~~~ Movie: ~~~~~~~~~~~~~~~~~~~~~~~~~~- ~~~~ Special: ~~~~~~ A Few More:
#   Description 2: The genre is Dramas. Describe a typical Dramas TV show:  Season 2-2, series 1-4, or series 5 and what their characters like. What it looked like in season 2
# As an addendum to what
#   Description 3: The genre is Dramas. Describe a typical Dramas TV show:  "A classic show about an elite couple going on a romance vacation, only to find it goes horribly wrong. The character you're assigned to play is completely uninteresting
#
#
# Genre: Thrillers
#   Description 1: The genre is Thrillers. Describe a typical Thrillers TV show:  (the first is "I Can't Sleep Here," the second "The Deadliest Catchup," and the final installment is "I Don't Remember.")
#   Description 2: The genre is Thrillers. Describe a typical Thrillers TV show:  " A character shows up, he is a real-life celebrity, he is just hanging out with friends." (This sort of shows up in movies and
#   Description 3: The genre is Thrillers. Describe a typical Thrillers TV show:  You're a kid who gets sucked into a TV show and finds a way to live this way and then you figure out the real, honest answer.
#
#
# Genre: British TV Shows
#   Description 1: The genre is British TV Shows. Describe a typical British TV Shows TV show:  A British TV show is one episode of a series of TV Show that have been aired in the UK. If you list the BBC show in categories that are
#   Description 2: The genre is British TV Shows. Describe a typical British TV Shows TV show: __________________________________________________________________________________________________________________________________ Episode 9. "The Shitty Woman" (season five, episode three; originally aired November 27, 2005) __________________________________________________________________________________________________________________________________ * *
#   Description 3: The genre is British TV Shows. Describe a typical British TV Shows TV show:  "In the middle of the middle ages there are about fifty British television shows going on now and these show are going on to make the greatest impact."
#
#
# Genre: TV Thrillers
#   Description 1: The genre is TV Thrillers. Describe a typical TV Thrillers TV show:  There's a lot of TV Thrillers that you want to watch in that show. It's an action movie or something. The show doesn
#   Description 2: The genre is TV Thrillers. Describe a typical TV Thrillers TV show:  Do you plan on watching an episode every week?  Do you get any scripts in on when they'll take place?  Do you
#   Description 3: The genre is TV Thrillers. Describe a typical TV Thrillers TV show:  "A lot of actors go through a similar period of their career and get the opportunity to work in these roles but this was one of the first
#
#
# Genre: Science & Nature TV
#   Description 1: The genre is Science & Nature TV. Describe a typical Science & Nature TV TV show:  (or TV show about a common topic... I'll add it in the comments ) 1.) (1) We've all watched '60s
#   Description 2: The genre is Science & Nature TV. Describe a typical Science & Nature TV TV show:  how the show is aired:  "What kind of science has caused this?", "What's in the science?" and "What's done
#   Description 3: The genre is Science & Nature TV. Describe a typical Science & Nature TV TV show:  Describe a typical Science & Nature TV show:  Examples of scientific and technical TV show examples
# You can find many examples of the show
#
#
# Genre: TV Sci-Fi & Fantasy
#   Description 1: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  "This is the second season of the Emmy winning TV series."  "This is the second season of the Emmy winning
#   Description 2: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  In one of the earliest productions, Star Trek and Babylon 5 were the first shows on the Paramount Television Network that could play as
#   Description 3: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  A young woman on a bus goes to school and her brother comes to her house and they take their lessons. In the meantime
#
#
# Genre: Faith & Spirituality
#   Description 1: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show:  what happens to your life as you make up your mind on God?  How do you decide if or when you will change your life and
#   Description 2: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show: ************* The show revolves around a pastor's belief that every person in the world should have a place in peace. He or she believes in Christ but
#   Description 3: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show:  What kind of faith is it? The answer is one that is at odds with how we think. If the show were truly centered on spiritual values
#
#
# Genre: Children & Family Movies
#   Description 1: The genre is Children & Family Movies. Describe a typical Children & Family Movies TV show: ___________________________________ "Child-like," "Family"-type drama. For a complete and comprehensive list of TV programs, check out this helpful "Guide to
#   Description 2: The genre is Children & Family Movies. Describe a typical Children & Family Movies TV show:  - How are kids enjoying Children & Family Movies?  - What was the main thing people love and want to get their kids to?
#   Description 3: The genre is Children & Family Movies. Describe a typical Children & Family Movies TV show:  "Children & Family Movies is what I look for when I try to tell an original story and when I try to present a 'perfect' story
#
#
# Genre: Movies
#   Description 1: The genre is Movies. Describe a typical Movies TV show:  1. When the character is in a very similar situation (like a young person or a man with a big problem) 3. When the character starts to make a decision
#   Description 2: The genre is Movies. Describe a typical Movies TV show:  Hollywood shows, such as: Gremlins, Parks and Recreation. Show The New Normal:  Parks and Recreation, which follows former New York City Police chief
#   Description 3: The genre is Movies. Describe a typical Movies TV show:  Show 1 show.    Describe a Movies TV show (not show 1):  If not describe a Movie, describe a Movie TV show (how long you
#
#
# Genre: TV Mysteries
#   Description 1: The genre is TV Mysteries. Describe a typical TV Mysteries TV show:  a scene of an ordinary household with some odd situation that they have to solve. How do you describe what they are going through?  You may be asking too
#   Description 2: The genre is TV Mysteries. Describe a typical TV Mysteries TV show:  We would pick a typical TV show and then pick a classic TV series to describe. The name usually starts with something that you see on TV in the first place.
#   Description 3: The genre is TV Mysteries. Describe a typical TV Mysteries TV show:  "It has to be really tough, and the challenge is to figure out if it actually works or not. We have all those people and we have all those producers
#
#
# Genre: Documentaries
#   Description 1: The genre is Documentaries. Describe a typical Documentaries TV show:  What does the main character do the whole time?  How do we deal with different forms of abuse?  What is being taught to a particular person?
#   Description 2: The genre is Documentaries. Describe a typical Documentaries TV show:  - The first part of the show has a typical format - most series have three or four episodes each.  The second part is about a group of individuals who
#   Description 3: The genre is Documentaries. Describe a typical Documentaries TV show:  - (1) The  American Gang  was first introduced in 1955, at the  Television Network Television  station in Manhattan, and
#
#
# Genre: Cult Movies
#   Description 1: The genre is Cult Movies. Describe a typical Cult Movies TV show:  "This genre of cult television shows is produced by cult actors. This kind of TV shows usually includes some genre-specific characters, supernatural or otherwise. Cult artists have
#   Description 2: The genre is Cult Movies. Describe a typical Cult Movies TV show:  the show is filled with cult classic movies like The Devil Wears Prada, The Last of Us  is a cult classic, or the series' first season
#   Description 3: The genre is Cult Movies. Describe a typical Cult Movies TV show:  - The main character (the protagonist of the show) spends his night (or he has a night) at a bar.
# - The main character spends his
#
#
# Genre: Romantic TV Shows
#   Description 1: The genre is Romantic TV Shows. Describe a typical Romantic TV Shows TV show:  Season 1 - Episode 1 :  The main attraction and one of the main themes (or two main themes) at the time is the relationship between
#   Description 2: The genre is Romantic TV Shows. Describe a typical Romantic TV Shows TV show: __________________________________________________________________________ Show Caster's Page: http://www.spieliknightly.com/show/2/1/show-caster-
#   Description 3: The genre is Romantic TV Shows. Describe a typical Romantic TV Shows TV show: ิารกอีาน (เบ่า้า, �
#
#
# Genre: TV Shows
#   Description 1: The genre is TV Shows. Describe a typical TV Shows TV show:  The  show  you are watching is shown  at least  once weekly from the web  by the viewer.  The show starts in a diner and moves
#   Description 2: The genre is TV Shows. Describe a typical TV Shows TV show: ~~~~~~~~~~~~ ~~~~~~~~. Episode 1 Episode 1 ~~~~~~~~~~~~ ~~~~~~~~~~~~ ~~~~~~~~. Episode 2 Episode 3 Season 2 ~~~~~~~~~~~~ ~~~~~~~~~~~~ ~~~~~~~~. Episode
#   Description 3: The genre is TV Shows. Describe a typical TV Shows TV show:  "We created our show to be in the spirit of the show we created. In the first place we wrote in English, and we know it's not going to

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
def determine_closest_genre(desc, genre_desc_map):
    print("Determining closest genre...")
    highest_similarity = 0
    closest_genre = None
    for genre, descs in genre_desc_map.items():
        for gen_desc in descs:
            sim_score = fuzz.token_sort_ratio(desc.lower(), gen_desc.lower())
            if sim_score > highest_similarity:
                highest_similarity = sim_score
                closest_genre = genre
    return closest_genre

# %%
for idx, row in df.iterrows():
    assigned_genre = determine_closest_genre(row['description'], genre_descriptions)
    df.at[idx, 'generated_genre'] = assigned_genre
# Out:
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# Determining closest genre...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-80d8dbc50831> in <cell line: 1>()
#       1 for idx, row in df.iterrows():
# ----> 2     assigned_genre = determine_closest_genre(row['description'], genre_descriptions)
#       3     df.at[idx, 'generated_genre'] = assigned_genre
#
# <ipython-input-24-b399ebff5faa> in determine_closest_genre(desc, genre_desc_map)
#       5     for genre, descs in genre_desc_map.items():
#       6         for gen_desc in descs:
# ----> 7             sim_score = fuzz.token_sort_ratio(desc.lower(), gen_desc.lower())
#       8             if sim_score > highest_similarity:
#       9                 highest_similarity = sim_score
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in token_sort_ratio(s1, s2, force_ascii, full_process)
#     103     but sorting the token before comparing.
#     104     """
# --> 105     return _token_sort(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in _token_sort(s1, s2, partial, force_ascii, full_process)
#      96         return partial_ratio(sorted1, sorted2)
#      97     else:
# ---> 98         return ratio(sorted1, sorted2)
#      99
#     100
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in ratio(s1, s2)
#      26
#      27     m = SequenceMatcher(None, s1, s2)
# ---> 28     return utils.intr(100 * m.ratio())
#      29
#      30
#
# /usr/lib/python3.10/difflib.py in ratio(self)
#     617         """
#     618
# --> 619         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     621
#
# /usr/lib/python3.10/difflib.py in get_matching_blocks(self)
#     452         while queue:
#     453             alo, ahi, blo, bhi = queue.pop()
# --> 454             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455             # a[alo:i] vs b[blo:j] unknown
#     456             # a[i:i+k] same as b[j:j+k]
#
# /usr/lib/python3.10/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     384                     break
#     385                 k = newj2len[j] = j2lenget(j-1, 0) + 1
# --> 386                 if k > bestsize:
#     387                     besti, bestj, bestsize = i-k+1, j-k+1, k
#     388             j2len = newj2len
#
# KeyboardInterrupt:

# %%
print("Evaluating accuracy...")
accuracy_dict = defaultdict(int)
count_dict = defaultdict(int)

for idx, row in df.iterrows():
    real_genres = row['listed_in'].split(", ")
    if row['generated_genre'] in real_genres:
        accuracy_dict[row['generated_genre']] += 1
    for genre in real_genres:
        count_dict[genre] += 1

for genre in count_dict:
    if count_dict[genre] > 0:
        print(f"Accuracy for {genre}: {accuracy_dict[genre] / count_dict[genre]:.2f}")
# Out:
# Evaluating accuracy...
# Accuracy for Documentaries: 0.02
# Accuracy for International TV Shows: 0.00
# Accuracy for TV Dramas: 0.04
# Accuracy for TV Mysteries: 0.00
# Accuracy for Crime TV Shows: 0.01
# Accuracy for TV Action & Adventure: 0.01
# Accuracy for Docuseries: 0.09
# Accuracy for Reality TV: 0.01
# Accuracy for Romantic TV Shows: 0.00
# Accuracy for TV Comedies: 0.08
# Accuracy for TV Horror: 0.05
# Accuracy for Children & Family Movies: 0.00
# Accuracy for Dramas: 0.02
# Accuracy for Independent Movies: 0.01
# Accuracy for International Movies: 0.00
# Accuracy for British TV Shows: 0.00
# Accuracy for Comedies: 0.02
# Accuracy for Spanish-Language TV Shows: 0.02
# Accuracy for Thrillers: 0.04
# Accuracy for Romantic Movies: 0.04
# Accuracy for Music & Musicals: 0.02
# Accuracy for Horror Movies: 0.04
# Accuracy for Sci-Fi & Fantasy: 0.02
# Accuracy for TV Thrillers: 0.00
# Accuracy for Kids' TV: 0.05
# Accuracy for Action & Adventure: 0.01
# Accuracy for TV Sci-Fi & Fantasy: 0.04
# Accuracy for Classic Movies: 0.01
# Accuracy for Anime Features: 0.04
# Accuracy for Sports Movies: 0.00
# Accuracy for Anime Series: 0.05
# Accuracy for Korean TV Shows: 0.00
# Accuracy for Science & Nature TV: 0.02
# Accuracy for Teen TV Shows: 0.00
# Accuracy for Cult Movies: 0.00
# Accuracy for TV Shows: 0.00
# Accuracy for Faith & Spirituality: 0.00
# Accuracy for LGBTQ Movies: 0.00
# Accuracy for Stand-Up Comedy: 0.09
# Accuracy for Movies: 0.00
# Accuracy for Stand-Up Comedy & Talk Shows: 0.00
# Accuracy for Classic & Cult TV: 0.00

# %%
#print("Re-assigning genres based on primary genre match...")
for idx, row in df.iterrows():
    main_genre = row['listed_in'].split(', ')[0]  # Extracting the primary genre from the 'listed_in' field
    generated_genre = row['generated_genre']  # The genre predicted based on the description

    if generated_genre != main_genre:
        # If the generated genre doesn't match the primary genre, re-assign and print the change
        df.at[idx, 'corrected_genre'] = main_genre
        print(f"Row {idx} corrected: {generated_genre} -> {main_genre}")
    else:
        # If they match, just set the corrected genre to be the same as the generated one
        df.at[idx, 'corrected_genre'] = generated_genre
# Out:
# Streaming output truncated to the last 5000 lines.
# Row 3750 corrected: Anime Series -> British TV Shows
# Row 3751 corrected: TV Horror -> TV Comedies
# Row 3752 corrected: Music & Musicals -> Crime TV Shows
# Row 3753 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 3754 corrected: Science & Nature TV -> Crime TV Shows
# Row 3755 corrected: Horror Movies -> International TV Shows
# Row 3756 corrected: Cult Movies -> Documentaries
# Row 3757 corrected: Science & Nature TV -> Horror Movies
# Row 3758 corrected: Docuseries -> Stand-Up Comedy
# Row 3759 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 3760 corrected: Stand-Up Comedy -> Kids' TV
# Row 3761 corrected: Docuseries -> Dramas
# Row 3762 corrected: Horror Movies -> Crime TV Shows
# Row 3763 corrected: Horror Movies -> Dramas
# Row 3764 corrected: Romantic Movies -> International Movies
# Row 3765 corrected: Dramas -> Comedies
# Row 3766 corrected: TV Dramas -> Children & Family Movies
# Row 3767 corrected: TV Action & Adventure -> Children & Family Movies
# Row 3768 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 3769 corrected: Sports Movies -> Kids' TV
# Row 3770 corrected: TV Comedies -> TV Dramas
# Row 3771 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 3772 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 3773 corrected: Comedies -> Anime Features
# Row 3774 corrected: TV Sci-Fi & Fantasy -> British TV Shows
# Row 3775 corrected: Horror Movies -> Dramas
# Row 3776 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 3777 corrected: TV Shows -> Children & Family Movies
# Row 3778 corrected: Sci-Fi & Fantasy -> TV Comedies
# Row 3779 corrected: Thrillers -> Kids' TV
# Row 3780 corrected: TV Horror -> International TV Shows
# Row 3781 corrected: Faith & Spirituality -> Dramas
# Row 3782 corrected: Anime Series -> International TV Shows
# Row 3783 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 3784 corrected: Romantic Movies -> Anime Series
# Row 3785 corrected: TV Comedies -> Comedies
# Row 3786 corrected: Kids' TV -> Action & Adventure
# Row 3787 corrected: Stand-Up Comedy -> Crime TV Shows
# Row 3788 corrected: Dramas -> Comedies
# Row 3789 corrected: TV Comedies -> Crime TV Shows
# Row 3790 corrected: LGBTQ Movies -> Dramas
# Row 3792 corrected: Anime Features -> Crime TV Shows
# Row 3793 corrected: International TV Shows -> International Movies
# Row 3794 corrected: Horror Movies -> Stand-Up Comedy & Talk Shows
# Row 3795 corrected: TV Sci-Fi & Fantasy -> Documentaries
# Row 3796 corrected: TV Comedies -> Docuseries
# Row 3797 corrected: TV Comedies -> Dramas
# Row 3798 corrected: Stand-Up Comedy -> Action & Adventure
# Row 3799 corrected: Dramas -> Romantic TV Shows
# Row 3800 corrected: TV Horror -> Horror Movies
# Row 3801 corrected: TV Sci-Fi & Fantasy -> TV Dramas
# Row 3802 corrected: Spanish-Language TV Shows -> Comedies
# Row 3803 corrected: Thrillers -> Documentaries
# Row 3804 corrected: TV Sci-Fi & Fantasy -> Action & Adventure
# Row 3806 corrected: Reality TV -> Kids' TV
# Row 3807 corrected: TV Shows -> Crime TV Shows
# Row 3808 corrected: Classic Movies -> Crime TV Shows
# Row 3809 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 3810 corrected: Thrillers -> Documentaries
# Row 3811 corrected: Dramas -> Documentaries
# Row 3812 corrected: Classic Movies -> TV Comedies
# Row 3813 corrected: Kids' TV -> Action & Adventure
# Row 3814 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 3816 corrected: Romantic Movies -> Dramas
# Row 3817 corrected: Anime Series -> British TV Shows
# Row 3818 corrected: Sports Movies -> Children & Family Movies
# Row 3819 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 3820 corrected: Thrillers -> Children & Family Movies
# Row 3821 corrected: Kids' TV -> British TV Shows
# Row 3822 corrected: Stand-Up Comedy -> Dramas
# Row 3823 corrected: Classic Movies -> Kids' TV
# Row 3824 corrected: Crime TV Shows -> International TV Shows
# Row 3825 corrected: Kids' TV -> Action & Adventure
# Row 3826 corrected: Kids' TV -> Anime Series
# Row 3827 corrected: Stand-Up Comedy -> Comedies
# Row 3828 corrected: Dramas -> Documentaries
# Row 3829 corrected: Stand-Up Comedy -> Children & Family Movies
# Row 3830 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 3831 corrected: Kids' TV -> Crime TV Shows
# Row 3832 corrected: Crime TV Shows -> Dramas
# Row 3833 corrected: Kids' TV -> Dramas
# Row 3834 corrected: Horror Movies -> Action & Adventure
# Row 3835 corrected: Classic & Cult TV -> TV Comedies
# Row 3836 corrected: Classic Movies -> Comedies
# Row 3837 corrected: TV Dramas -> Docuseries
# Row 3838 corrected: Comedies -> Crime TV Shows
# Row 3839 corrected: Faith & Spirituality -> International TV Shows
# Row 3841 corrected: Romantic Movies -> Comedies
# Row 3842 corrected: TV Shows -> Action & Adventure
# Row 3843 corrected: Cult Movies -> International TV Shows
# Row 3844 corrected: Romantic Movies -> International TV Shows
# Row 3845 corrected: Dramas -> International TV Shows
# Row 3846 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 3847 corrected: TV Comedies -> International TV Shows
# Row 3848 corrected: Romantic Movies -> International TV Shows
# Row 3849 corrected: Docuseries -> International TV Shows
# Row 3850 corrected: Horror Movies -> International TV Shows
# Row 3851 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 3852 corrected: TV Dramas -> Crime TV Shows
# Row 3853 corrected: Anime Series -> International TV Shows
# Row 3854 corrected: TV Horror -> International TV Shows
# Row 3855 corrected: TV Horror -> Crime TV Shows
# Row 3856 corrected: Independent Movies -> International TV Shows
# Row 3857 corrected: Docuseries -> Documentaries
# Row 3858 corrected: Thrillers -> International Movies
# Row 3859 corrected: Docuseries -> Documentaries
# Row 3860 corrected: Anime Features -> Crime TV Shows
# Row 3861 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 3862 corrected: Action & Adventure -> Comedies
# Row 3863 corrected: TV Comedies -> Dramas
# Row 3864 corrected: Classic Movies -> Reality TV
# Row 3865 corrected: Stand-Up Comedy & Talk Shows -> Dramas
# Row 3866 corrected: Docuseries -> Comedies
# Row 3868 corrected: Kids' TV -> Comedies
# Row 3869 corrected: Anime Series -> Action & Adventure
# Row 3870 corrected: TV Dramas -> Anime Series
# Row 3871 corrected: Sports Movies -> Documentaries
# Row 3872 corrected: Music & Musicals -> Documentaries
# Row 3873 corrected: Thrillers -> Horror Movies
# Row 3874 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 3876 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 3877 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 3878 corrected: TV Shows -> International TV Shows
# Row 3879 corrected: Horror Movies -> Anime Series
# Row 3880 corrected: TV Comedies -> International TV Shows
# Row 3881 corrected: Dramas -> International TV Shows
# Row 3882 corrected: TV Thrillers -> International TV Shows
# Row 3883 corrected: Thrillers -> Crime TV Shows
# Row 3884 corrected: Thrillers -> TV Action & Adventure
# Row 3885 corrected: TV Horror -> Dramas
# Row 3886 corrected: Docuseries -> Crime TV Shows
# Row 3887 corrected: Comedies -> TV Horror
# Row 3888 corrected: Sci-Fi & Fantasy -> Comedies
# Row 3889 corrected: Music & Musicals -> Comedies
# Row 3890 corrected: Sci-Fi & Fantasy -> Comedies
# Row 3891 corrected: Docuseries -> Documentaries
# Row 3893 corrected: TV Dramas -> TV Shows
# Row 3894 corrected: Romantic Movies -> Dramas
# Row 3895 corrected: Music & Musicals -> Documentaries
# Row 3896 corrected: Anime Features -> Documentaries
# Row 3897 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 3898 corrected: Anime Series -> International TV Shows
# Row 3899 corrected: Classic Movies -> Dramas
# Row 3900 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 3901 corrected: TV Sci-Fi & Fantasy -> Anime Series
# Row 3902 corrected: Thrillers -> International TV Shows
# Row 3903 corrected: TV Action & Adventure -> Comedies
# Row 3904 corrected: TV Dramas -> Dramas
# Row 3905 corrected: Romantic Movies -> Dramas
# Row 3906 corrected: Sci-Fi & Fantasy -> Stand-Up Comedy
# Row 3907 corrected: Romantic Movies -> Documentaries
# Row 3908 corrected: Children & Family Movies -> Comedies
# Row 3909 corrected: Movies -> Children & Family Movies
# Row 3910 corrected: Kids' TV -> Comedies
# Row 3911 corrected: Independent Movies -> International Movies
# Row 3912 corrected: TV Comedies -> Documentaries
# Row 3913 corrected: Thrillers -> Dramas
# Row 3914 corrected: Docuseries -> Comedies
# Row 3915 corrected: TV Action & Adventure -> Comedies
# Row 3916 corrected: Cult Movies -> Dramas
# Row 3917 corrected: Stand-Up Comedy -> Dramas
# Row 3918 corrected: TV Sci-Fi & Fantasy -> Action & Adventure
# Row 3919 corrected: TV Comedies -> Horror Movies
# Row 3920 corrected: Thrillers -> Romantic TV Shows
# Row 3921 corrected: Romantic Movies -> Dramas
# Row 3922 corrected: Sci-Fi & Fantasy -> Horror Movies
# Row 3923 corrected: TV Horror -> Horror Movies
# Row 3926 corrected: Action & Adventure -> Comedies
# Row 3927 corrected: Action & Adventure -> Romantic TV Shows
# Row 3928 corrected: LGBTQ Movies -> International TV Shows
# Row 3929 corrected: Romantic Movies -> Stand-Up Comedy
# Row 3930 corrected: Kids' TV -> Horror Movies
# Row 3932 corrected: TV Comedies -> Dramas
# Row 3933 corrected: Anime Series -> Action & Adventure
# Row 3934 corrected: TV Horror -> Docuseries
# Row 3935 corrected: Comedies -> Action & Adventure
# Row 3936 corrected: Kids' TV -> British TV Shows
# Row 3937 corrected: Sci-Fi & Fantasy -> Crime TV Shows
# Row 3938 corrected: TV Comedies -> Docuseries
# Row 3939 corrected: Anime Series -> Action & Adventure
# Row 3940 corrected: Anime Series -> Crime TV Shows
# Row 3941 corrected: TV Comedies -> Kids' TV
# Row 3942 corrected: Independent Movies -> Docuseries
# Row 3943 corrected: Thrillers -> Kids' TV
# Row 3944 corrected: Romantic Movies -> Crime TV Shows
# Row 3945 corrected: Docuseries -> Comedies
# Row 3946 corrected: Docuseries -> Crime TV Shows
# Row 3947 corrected: TV Comedies -> Stand-Up Comedy
# Row 3948 corrected: Faith & Spirituality -> Horror Movies
# Row 3949 corrected: Action & Adventure -> International TV Shows
# Row 3950 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 3951 corrected: Horror Movies -> Dramas
# Row 3952 corrected: Independent Movies -> Stand-Up Comedy
# Row 3953 corrected: Sci-Fi & Fantasy -> Kids' TV
# Row 3954 corrected: Movies -> International Movies
# Row 3955 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 3956 corrected: Science & Nature TV -> International TV Shows
# Row 3957 corrected: Thrillers -> Comedies
# Row 3958 corrected: Kids' TV -> Anime Series
# Row 3959 corrected: Comedies -> Horror Movies
# Row 3960 corrected: Music & Musicals -> Dramas
# Row 3961 corrected: Thrillers -> British TV Shows
# Row 3962 corrected: TV Dramas -> Comedies
# Row 3963 corrected: Independent Movies -> Dramas
# Row 3964 corrected: Anime Series -> International TV Shows
# Row 3965 corrected: Stand-Up Comedy -> TV Comedies
# Row 3966 corrected: Sports Movies -> Dramas
# Row 3967 corrected: Classic Movies -> Documentaries
# Row 3968 corrected: Stand-Up Comedy -> International TV Shows
# Row 3969 corrected: Thrillers -> British TV Shows
# Row 3970 corrected: TV Comedies -> International TV Shows
# Row 3971 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 3973 corrected: Stand-Up Comedy -> Dramas
# Row 3974 corrected: Docuseries -> Stand-Up Comedy
# Row 3975 corrected: TV Action & Adventure -> Action & Adventure
# Row 3976 corrected: TV Dramas -> Crime TV Shows
# Row 3977 corrected: Horror Movies -> Action & Adventure
# Row 3978 corrected: Sports Movies -> Action & Adventure
# Row 3979 corrected: Horror Movies -> Kids' TV
# Row 3980 corrected: TV Comedies -> Crime TV Shows
# Row 3981 corrected: TV Comedies -> Crime TV Shows
# Row 3982 corrected: TV Dramas -> Dramas
# Row 3983 corrected: Horror Movies -> Documentaries
# Row 3984 corrected: Sports Movies -> International TV Shows
# Row 3985 corrected: Science & Nature TV -> Comedies
# Row 3986 corrected: Kids' TV -> TV Dramas
# Row 3987 corrected: TV Comedies -> Documentaries
# Row 3988 corrected: Stand-Up Comedy -> Kids' TV
# Row 3989 corrected: Thrillers -> International TV Shows
# Row 3990 corrected: TV Dramas -> Action & Adventure
# Row 3991 corrected: Thrillers -> Action & Adventure
# Row 3992 corrected: Anime Series -> Comedies
# Row 3993 corrected: Stand-Up Comedy -> Dramas
# Row 3994 corrected: Action & Adventure -> International Movies
# Row 3995 corrected: TV Comedies -> Documentaries
# Row 3996 corrected: Docuseries -> International TV Shows
# Row 3997 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 3998 corrected: TV Comedies -> International TV Shows
# Row 3999 corrected: Sports Movies -> Stand-Up Comedy
# Row 4000 corrected: Stand-Up Comedy -> Comedies
# Row 4001 corrected: TV Comedies -> International TV Shows
# Row 4002 corrected: Thrillers -> Comedies
# Row 4003 corrected: Cult Movies -> Action & Adventure
# Row 4004 corrected: TV Comedies -> Stand-Up Comedy
# Row 4005 corrected: Anime Features -> Dramas
# Row 4006 corrected: TV Comedies -> International TV Shows
# Row 4007 corrected: Docuseries -> Stand-Up Comedy
# Row 4008 corrected: Dramas -> Stand-Up Comedy
# Row 4009 corrected: Thrillers -> Stand-Up Comedy
# Row 4010 corrected: Thrillers -> Stand-Up Comedy
# Row 4012 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 4013 corrected: Horror Movies -> Action & Adventure
# Row 4014 corrected: TV Sci-Fi & Fantasy -> British TV Shows
# Row 4015 corrected: Horror Movies -> Crime TV Shows
# Row 4016 corrected: Sci-Fi & Fantasy -> British TV Shows
# Row 4017 corrected: Cult Movies -> Dramas
# Row 4018 corrected: Action & Adventure -> Dramas
# Row 4019 corrected: Docuseries -> Comedies
# Row 4020 corrected: Sci-Fi & Fantasy -> International Movies
# Row 4021 corrected: Sci-Fi & Fantasy -> Comedies
# Row 4022 corrected: Cult Movies -> International TV Shows
# Row 4023 corrected: Thrillers -> International TV Shows
# Row 4024 corrected: Stand-Up Comedy -> Action & Adventure
# Row 4025 corrected: Cult Movies -> Stand-Up Comedy
# Row 4026 corrected: TV Comedies -> International TV Shows
# Row 4027 corrected: Thrillers -> International TV Shows
# Row 4028 corrected: TV Sci-Fi & Fantasy -> TV Action & Adventure
# Row 4029 corrected: Romantic Movies -> International TV Shows
# Row 4030 corrected: Horror Movies -> International TV Shows
# Row 4031 corrected: Docuseries -> Action & Adventure
# Row 4032 corrected: Reality TV -> International TV Shows
# Row 4033 corrected: Anime Series -> Dramas
# Row 4034 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4035 corrected: TV Action & Adventure -> International TV Shows
# Row 4036 corrected: TV Comedies -> Children & Family Movies
# Row 4037 corrected: Stand-Up Comedy -> Comedies
# Row 4038 corrected: Stand-Up Comedy -> Comedies
# Row 4039 corrected: TV Comedies -> Dramas
# Row 4040 corrected: Romantic Movies -> Dramas
# Row 4041 corrected: Docuseries -> Dramas
# Row 4042 corrected: Sports Movies -> Crime TV Shows
# Row 4043 corrected: TV Comedies -> International TV Shows
# Row 4044 corrected: Horror Movies -> International TV Shows
# Row 4045 corrected: Romantic Movies -> Action & Adventure
# Row 4046 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4047 corrected: Thrillers -> Dramas
# Row 4048 corrected: Horror Movies -> Dramas
# Row 4049 corrected: Docuseries -> Action & Adventure
# Row 4050 corrected: Sports Movies -> Documentaries
# Row 4051 corrected: Kids' TV -> Documentaries
# Row 4052 corrected: TV Horror -> Documentaries
# Row 4053 corrected: Thrillers -> Comedies
# Row 4054 corrected: Science & Nature TV -> Docuseries
# Row 4055 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4056 corrected: Anime Series -> Docuseries
# Row 4057 corrected: Thrillers -> TV Dramas
# Row 4058 corrected: Comedies -> Children & Family Movies
# Row 4059 corrected: Stand-Up Comedy -> Horror Movies
# Row 4060 corrected: Stand-Up Comedy & Talk Shows -> Children & Family Movies
# Row 4061 corrected: TV Comedies -> Dramas
# Row 4062 corrected: Science & Nature TV -> Children & Family Movies
# Row 4063 corrected: Sci-Fi & Fantasy -> Anime Series
# Row 4064 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4065 corrected: Cult Movies -> Children & Family Movies
# Row 4066 corrected: TV Dramas -> Dramas
# Row 4067 corrected: Kids' TV -> Dramas
# Row 4068 corrected: TV Action & Adventure -> Dramas
# Row 4069 corrected: TV Comedies -> Action & Adventure
# Row 4070 corrected: Thrillers -> Comedies
# Row 4071 corrected: Kids' TV -> Comedies
# Row 4072 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4073 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4074 corrected: TV Comedies -> Comedies
# Row 4075 corrected: Anime Series -> Comedies
# Row 4076 corrected: TV Comedies -> Dramas
# Row 4077 corrected: TV Comedies -> Dramas
# Row 4078 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4079 corrected: TV Dramas -> Crime TV Shows
# Row 4080 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 4081 corrected: Docuseries -> Dramas
# Row 4082 corrected: TV Comedies -> Dramas
# Row 4085 corrected: Comedies -> Dramas
# Row 4086 corrected: Docuseries -> Comedies
# Row 4087 corrected: Sports Movies -> Dramas
# Row 4088 corrected: Thrillers -> Dramas
# Row 4089 corrected: Dramas -> British TV Shows
# Row 4090 corrected: Sports Movies -> Kids' TV
# Row 4091 corrected: Documentaries -> Dramas
# Row 4092 corrected: Sports Movies -> Stand-Up Comedy
# Row 4093 corrected: Kids' TV -> Documentaries
# Row 4094 corrected: Faith & Spirituality -> Dramas
# Row 4095 corrected: Stand-Up Comedy -> Action & Adventure
# Row 4097 corrected: Docuseries -> Dramas
# Row 4098 corrected: Crime TV Shows -> Dramas
# Row 4099 corrected: TV Shows -> Documentaries
# Row 4100 corrected: Romantic Movies -> Comedies
# Row 4101 corrected: TV Dramas -> Dramas
# Row 4102 corrected: Anime Features -> Dramas
# Row 4103 corrected: Horror Movies -> Comedies
# Row 4104 corrected: Cult Movies -> International TV Shows
# Row 4105 corrected: LGBTQ Movies -> Docuseries
# Row 4106 corrected: Stand-Up Comedy -> Dramas
# Row 4107 corrected: TV Comedies -> Comedies
# Row 4108 corrected: Music & Musicals -> Dramas
# Row 4109 corrected: Documentaries -> Crime TV Shows
# Row 4110 corrected: Romantic Movies -> Comedies
# Row 4111 corrected: Horror Movies -> International TV Shows
# Row 4112 corrected: Kids' TV -> Comedies
# Row 4113 corrected: TV Comedies -> Comedies
# Row 4114 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4115 corrected: Anime Series -> Stand-Up Comedy
# Row 4116 corrected: Thrillers -> International TV Shows
# Row 4117 corrected: Independent Movies -> Documentaries
# Row 4118 corrected: Comedies -> International TV Shows
# Row 4119 corrected: Music & Musicals -> Crime TV Shows
# Row 4120 corrected: TV Comedies -> Dramas
# Row 4121 corrected: LGBTQ Movies -> Children & Family Movies
# Row 4122 corrected: Classic Movies -> TV Comedies
# Row 4123 corrected: TV Comedies -> Documentaries
# Row 4124 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4125 corrected: Horror Movies -> International TV Shows
# Row 4126 corrected: Science & Nature TV -> Crime TV Shows
# Row 4127 corrected: Movies -> Crime TV Shows
# Row 4128 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 4129 corrected: Science & Nature TV -> British TV Shows
# Row 4130 corrected: TV Comedies -> International TV Shows
# Row 4132 corrected: TV Dramas -> International TV Shows
# Row 4133 corrected: TV Sci-Fi & Fantasy -> Horror Movies
# Row 4134 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4135 corrected: TV Sci-Fi & Fantasy -> Documentaries
# Row 4136 corrected: Music & Musicals -> Comedies
# Row 4137 corrected: Sci-Fi & Fantasy -> Children & Family Movies
# Row 4138 corrected: TV Shows -> Movies
# Row 4139 corrected: Anime Features -> Children & Family Movies
# Row 4140 corrected: TV Shows -> Children & Family Movies
# Row 4141 corrected: Thrillers -> Kids' TV
# Row 4142 corrected: Sports Movies -> TV Comedies
# Row 4143 corrected: LGBTQ Movies -> Crime TV Shows
# Row 4144 corrected: Classic Movies -> Anime Series
# Row 4145 corrected: Thrillers -> Children & Family Movies
# Row 4146 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4147 corrected: Faith & Spirituality -> Comedies
# Row 4148 corrected: Thrillers -> Comedies
# Row 4149 corrected: TV Action & Adventure -> Kids' TV
# Row 4150 corrected: TV Comedies -> Dramas
# Row 4151 corrected: Music & Musicals -> Dramas
# Row 4152 corrected: Kids' TV -> Dramas
# Row 4153 corrected: Documentaries -> Stand-Up Comedy
# Row 4154 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4155 corrected: LGBTQ Movies -> Dramas
# Row 4156 corrected: Kids' TV -> Documentaries
# Row 4157 corrected: Romantic Movies -> Dramas
# Row 4158 corrected: TV Comedies -> Dramas
# Row 4159 corrected: Thrillers -> Dramas
# Row 4160 corrected: Action & Adventure -> Dramas
# Row 4161 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4162 corrected: Anime Series -> International TV Shows
# Row 4163 corrected: TV Comedies -> TV Action & Adventure
# Row 4164 corrected: Anime Series -> Dramas
# Row 4165 corrected: TV Sci-Fi & Fantasy -> Horror Movies
# Row 4166 corrected: TV Dramas -> British TV Shows
# Row 4167 corrected: TV Comedies -> International TV Shows
# Row 4168 corrected: Stand-Up Comedy -> Crime TV Shows
# Row 4169 corrected: Independent Movies -> Comedies
# Row 4170 corrected: Romantic Movies -> Action & Adventure
# Row 4171 corrected: Stand-Up Comedy -> International TV Shows
# Row 4172 corrected: Horror Movies -> Crime TV Shows
# Row 4173 corrected: TV Comedies -> Dramas
# Row 4174 corrected: Romantic Movies -> Crime TV Shows
# Row 4175 corrected: Anime Series -> Action & Adventure
# Row 4176 corrected: TV Comedies -> Documentaries
# Row 4177 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4178 corrected: LGBTQ Movies -> Crime TV Shows
# Row 4179 corrected: TV Horror -> International TV Shows
# Row 4180 corrected: TV Comedies -> Documentaries
# Row 4181 corrected: TV Comedies -> Documentaries
# Row 4182 corrected: Kids' TV -> Dramas
# Row 4183 corrected: Children & Family Movies -> British TV Shows
# Row 4184 corrected: Dramas -> Docuseries
# Row 4185 corrected: Dramas -> Documentaries
# Row 4186 corrected: Thrillers -> Dramas
# Row 4187 corrected: Romantic Movies -> Comedies
# Row 4188 corrected: Kids' TV -> International Movies
# Row 4189 corrected: TV Shows -> International TV Shows
# Row 4190 corrected: Thrillers -> Action & Adventure
# Row 4191 corrected: Thrillers -> Horror Movies
# Row 4192 corrected: Comedies -> Action & Adventure
# Row 4193 corrected: TV Comedies -> Stand-Up Comedy
# Row 4194 corrected: Comedies -> Horror Movies
# Row 4195 corrected: Stand-Up Comedy -> Horror Movies
# Row 4196 corrected: Romantic Movies -> International TV Shows
# Row 4197 corrected: Romantic Movies -> Dramas
# Row 4198 corrected: Thrillers -> Comedies
# Row 4199 corrected: Anime Series -> International TV Shows
# Row 4200 corrected: TV Dramas -> Romantic TV Shows
# Row 4201 corrected: Kids' TV -> TV Comedies
# Row 4202 corrected: TV Comedies -> British TV Shows
# Row 4203 corrected: Horror Movies -> Documentaries
# Row 4204 corrected: Anime Series -> Dramas
# Row 4205 corrected: Stand-Up Comedy & Talk Shows -> Comedies
# Row 4207 corrected: Independent Movies -> International TV Shows
# Row 4208 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4209 corrected: TV Comedies -> Comedies
# Row 4210 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4211 corrected: Comedies -> Horror Movies
# Row 4212 corrected: Kids' TV -> Dramas
# Row 4213 corrected: Sports Movies -> Dramas
# Row 4214 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4215 corrected: TV Dramas -> International TV Shows
# Row 4216 corrected: TV Comedies -> International TV Shows
# Row 4217 corrected: Stand-Up Comedy -> Action & Adventure
# Row 4218 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4219 corrected: TV Dramas -> Comedies
# Row 4220 corrected: TV Comedies -> Stand-Up Comedy & Talk Shows
# Row 4222 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 4223 corrected: Docuseries -> Anime Features
# Row 4224 corrected: Romantic Movies -> International Movies
# Row 4225 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4226 corrected: TV Comedies -> International TV Shows
# Row 4227 corrected: Thrillers -> Reality TV
# Row 4228 corrected: Dramas -> Stand-Up Comedy
# Row 4229 corrected: TV Comedies -> Stand-Up Comedy
# Row 4230 corrected: Comedies -> Documentaries
# Row 4231 corrected: TV Comedies -> Stand-Up Comedy
# Row 4232 corrected: TV Sci-Fi & Fantasy -> Stand-Up Comedy
# Row 4233 corrected: Science & Nature TV -> Stand-Up Comedy
# Row 4234 corrected: TV Sci-Fi & Fantasy -> Stand-Up Comedy
# Row 4235 corrected: TV Comedies -> Stand-Up Comedy
# Row 4236 corrected: Independent Movies -> Documentaries
# Row 4237 corrected: Sports Movies -> Stand-Up Comedy
# Row 4238 corrected: Horror Movies -> Stand-Up Comedy
# Row 4239 corrected: Sports Movies -> Stand-Up Comedy
# Row 4240 corrected: Comedies -> Documentaries
# Row 4241 corrected: Kids' TV -> Comedies
# Row 4242 corrected: Anime Features -> Music & Musicals
# Row 4243 corrected: TV Horror -> Action & Adventure
# Row 4244 corrected: Dramas -> Stand-Up Comedy
# Row 4245 corrected: Anime Features -> Stand-Up Comedy
# Row 4246 corrected: Stand-Up Comedy -> Music & Musicals
# Row 4247 corrected: Comedies -> Music & Musicals
# Row 4248 corrected: Comedies -> Stand-Up Comedy
# Row 4250 corrected: TV Sci-Fi & Fantasy -> TV Shows
# Row 4251 corrected: Classic Movies -> Crime TV Shows
# Row 4252 corrected: TV Comedies -> Dramas
# Row 4253 corrected: Comedies -> Dramas
# Row 4254 corrected: Sci-Fi & Fantasy -> Crime TV Shows
# Row 4255 corrected: Children & Family Movies -> Action & Adventure
# Row 4256 corrected: Comedies -> Crime TV Shows
# Row 4257 corrected: Thrillers -> International TV Shows
# Row 4258 corrected: Horror Movies -> Documentaries
# Row 4259 corrected: Sci-Fi & Fantasy -> Dramas
# Row 4260 corrected: Thrillers -> Stand-Up Comedy & Talk Shows
# Row 4261 corrected: Thrillers -> International TV Shows
# Row 4262 corrected: Classic Movies -> British TV Shows
# Row 4263 corrected: TV Dramas -> Crime TV Shows
# Row 4264 corrected: Horror Movies -> British TV Shows
# Row 4265 corrected: Docuseries -> International TV Shows
# Row 4266 corrected: LGBTQ Movies -> Docuseries
# Row 4267 corrected: Sci-Fi & Fantasy -> Comedies
# Row 4268 corrected: Thrillers -> Dramas
# Row 4269 corrected: Docuseries -> International TV Shows
# Row 4270 corrected: Docuseries -> Anime Series
# Row 4271 corrected: TV Comedies -> International TV Shows
# Row 4272 corrected: TV Comedies -> International TV Shows
# Row 4273 corrected: Kids' TV -> Crime TV Shows
# Row 4275 corrected: Docuseries -> Documentaries
# Row 4276 corrected: Anime Series -> International TV Shows
# Row 4277 corrected: Anime Series -> Horror Movies
# Row 4278 corrected: Sci-Fi & Fantasy -> Movies
# Row 4279 corrected: Movies -> Anime Series
# Row 4280 corrected: Kids' TV -> Action & Adventure
# Row 4281 corrected: TV Dramas -> International Movies
# Row 4282 corrected: Thrillers -> Dramas
# Row 4283 corrected: Thrillers -> Dramas
# Row 4284 corrected: TV Sci-Fi & Fantasy -> Stand-Up Comedy & Talk Shows
# Row 4285 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4286 corrected: Horror Movies -> Children & Family Movies
# Row 4287 corrected: Kids' TV -> Comedies
# Row 4288 corrected: Dramas -> International TV Shows
# Row 4289 corrected: Comedies -> Children & Family Movies
# Row 4290 corrected: Anime Features -> Kids' TV
# Row 4291 corrected: Comedies -> Dramas
# Row 4292 corrected: Sci-Fi & Fantasy -> Comedies
# Row 4293 corrected: Sports Movies -> Music & Musicals
# Row 4294 corrected: Horror Movies -> Dramas
# Row 4295 corrected: TV Comedies -> Children & Family Movies
# Row 4296 corrected: Science & Nature TV -> British TV Shows
# Row 4297 corrected: Horror Movies -> Comedies
# Row 4298 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 4299 corrected: TV Comedies -> Documentaries
# Row 4300 corrected: TV Comedies -> Documentaries
# Row 4301 corrected: TV Comedies -> Documentaries
# Row 4302 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 4303 corrected: Docuseries -> Dramas
# Row 4304 corrected: Horror Movies -> International TV Shows
# Row 4305 corrected: Anime Features -> British TV Shows
# Row 4306 corrected: Horror Movies -> Dramas
# Row 4308 corrected: Comedies -> Crime TV Shows
# Row 4309 corrected: TV Comedies -> Crime TV Shows
# Row 4310 corrected: LGBTQ Movies -> Crime TV Shows
# Row 4311 corrected: Anime Features -> Kids' TV
# Row 4312 corrected: Romantic Movies -> Anime Series
# Row 4313 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 4314 corrected: TV Dramas -> Stand-Up Comedy
# Row 4315 corrected: Kids' TV -> Comedies
# Row 4316 corrected: Docuseries -> Crime TV Shows
# Row 4317 corrected: Kids' TV -> Comedies
# Row 4318 corrected: Anime Series -> Children & Family Movies
# Row 4319 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4320 corrected: Anime Features -> TV Comedies
# Row 4321 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 4322 corrected: Spanish-Language TV Shows -> Documentaries
# Row 4323 corrected: Comedies -> Children & Family Movies
# Row 4324 corrected: Classic Movies -> Documentaries
# Row 4325 corrected: LGBTQ Movies -> Stand-Up Comedy
# Row 4326 corrected: TV Comedies -> International TV Shows
# Row 4327 corrected: Cult Movies -> Crime TV Shows
# Row 4328 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4329 corrected: TV Comedies -> Dramas
# Row 4330 corrected: Docuseries -> International Movies
# Row 4331 corrected: Kids' TV -> Documentaries
# Row 4332 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4333 corrected: TV Action & Adventure -> Action & Adventure
# Row 4334 corrected: Romantic Movies -> Comedies
# Row 4335 corrected: Thrillers -> Comedies
# Row 4336 corrected: Kids' TV -> Dramas
# Row 4337 corrected: Docuseries -> Comedies
# Row 4338 corrected: Faith & Spirituality -> Comedies
# Row 4339 corrected: TV Sci-Fi & Fantasy -> Action & Adventure
# Row 4340 corrected: Dramas -> Kids' TV
# Row 4341 corrected: Kids' TV -> Action & Adventure
# Row 4342 corrected: Docuseries -> Action & Adventure
# Row 4343 corrected: Reality TV -> Comedies
# Row 4344 corrected: Independent Movies -> Movies
# Row 4345 corrected: Docuseries -> Action & Adventure
# Row 4346 corrected: TV Action & Adventure -> Dramas
# Row 4347 corrected: Thrillers -> Documentaries
# Row 4348 corrected: Anime Features -> Comedies
# Row 4349 corrected: Stand-Up Comedy -> Dramas
# Row 4350 corrected: Docuseries -> Crime TV Shows
# Row 4351 corrected: Reality TV -> Children & Family Movies
# Row 4352 corrected: TV Sci-Fi & Fantasy -> Children & Family Movies
# Row 4353 corrected: Comedies -> Reality TV
# Row 4354 corrected: Anime Features -> Dramas
# Row 4355 corrected: Thrillers -> Dramas
# Row 4356 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 4357 corrected: TV Comedies -> Dramas
# Row 4358 corrected: International TV Shows -> Comedies
# Row 4359 corrected: Anime Series -> Kids' TV
# Row 4360 corrected: Thrillers -> Action & Adventure
# Row 4361 corrected: TV Comedies -> Dramas
# Row 4362 corrected: Romantic Movies -> Stand-Up Comedy & Talk Shows
# Row 4363 corrected: TV Shows -> Kids' TV
# Row 4364 corrected: Romantic Movies -> Children & Family Movies
# Row 4365 corrected: TV Comedies -> International TV Shows
# Row 4366 corrected: TV Sci-Fi & Fantasy -> Crime TV Shows
# Row 4367 corrected: Thrillers -> British TV Shows
# Row 4368 corrected: Cult Movies -> TV Comedies
# Row 4369 corrected: Anime Features -> Children & Family Movies
# Row 4370 corrected: Thrillers -> Comedies
# Row 4371 corrected: TV Shows -> Kids' TV
# Row 4372 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4373 corrected: Stand-Up Comedy -> Children & Family Movies
# Row 4374 corrected: TV Comedies -> Horror Movies
# Row 4375 corrected: Romantic Movies -> Comedies
# Row 4376 corrected: Stand-Up Comedy -> Reality TV
# Row 4377 corrected: Dramas -> Stand-Up Comedy
# Row 4378 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 4379 corrected: Horror Movies -> International TV Shows
# Row 4380 corrected: TV Comedies -> Spanish-Language TV Shows
# Row 4381 corrected: TV Sci-Fi & Fantasy -> Romantic TV Shows
# Row 4382 corrected: Romantic Movies -> Horror Movies
# Row 4383 corrected: Thrillers -> Comedies
# Row 4384 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4385 corrected: TV Action & Adventure -> Comedies
# Row 4386 corrected: TV Thrillers -> Children & Family Movies
# Row 4387 corrected: Anime Series -> Docuseries
# Row 4390 corrected: Sci-Fi & Fantasy -> Comedies
# Row 4391 corrected: Docuseries -> Comedies
# Row 4392 corrected: Romantic Movies -> Horror Movies
# Row 4393 corrected: Kids' TV -> Documentaries
# Row 4394 corrected: Docuseries -> Comedies
# Row 4395 corrected: Music & Musicals -> Horror Movies
# Row 4396 corrected: Docuseries -> Dramas
# Row 4397 corrected: Cult Movies -> Action & Adventure
# Row 4398 corrected: Thrillers -> Music & Musicals
# Row 4399 corrected: Docuseries -> Crime TV Shows
# Row 4400 corrected: TV Horror -> Docuseries
# Row 4401 corrected: Docuseries -> Comedies
# Row 4402 corrected: Docuseries -> Comedies
# Row 4403 corrected: Horror Movies -> Docuseries
# Row 4404 corrected: Independent Movies -> Action & Adventure
# Row 4405 corrected: Dramas -> International TV Shows
# Row 4406 corrected: TV Sci-Fi & Fantasy -> Crime TV Shows
# Row 4407 corrected: TV Sci-Fi & Fantasy -> Kids' TV
# Row 4408 corrected: Sports Movies -> Reality TV
# Row 4409 corrected: TV Dramas -> Crime TV Shows
# Row 4410 corrected: TV Dramas -> Crime TV Shows
# Row 4411 corrected: Horror Movies -> Dramas
# Row 4412 corrected: Horror Movies -> Stand-Up Comedy
# Row 4413 corrected: TV Dramas -> International TV Shows
# Row 4414 corrected: TV Dramas -> Comedies
# Row 4415 corrected: Reality TV -> Kids' TV
# Row 4416 corrected: Kids' TV -> Documentaries
# Row 4417 corrected: Independent Movies -> Dramas
# Row 4418 corrected: TV Comedies -> Classic Movies
# Row 4419 corrected: Cult Movies -> Documentaries
# Row 4420 corrected: Stand-Up Comedy -> Comedies
# Row 4421 corrected: Cult Movies -> International Movies
# Row 4422 corrected: TV Action & Adventure -> Dramas
# Row 4423 corrected: Anime Series -> Dramas
# Row 4424 corrected: Stand-Up Comedy -> Action & Adventure
# Row 4426 corrected: Thrillers -> Comedies
# Row 4427 corrected: Stand-Up Comedy & Talk Shows -> Comedies
# Row 4428 corrected: Thrillers -> International Movies
# Row 4429 corrected: Classic Movies -> Comedies
# Row 4430 corrected: Stand-Up Comedy -> Kids' TV
# Row 4431 corrected: TV Comedies -> Dramas
# Row 4432 corrected: LGBTQ Movies -> Comedies
# Row 4433 corrected: LGBTQ Movies -> Comedies
# Row 4434 corrected: TV Sci-Fi & Fantasy -> Independent Movies
# Row 4435 corrected: TV Sci-Fi & Fantasy -> Stand-Up Comedy
# Row 4436 corrected: Kids' TV -> Docuseries
# Row 4437 corrected: Docuseries -> Dramas
# Row 4438 corrected: Horror Movies -> Comedies
# Row 4439 corrected: Docuseries -> International Movies
# Row 4440 corrected: Stand-Up Comedy -> Comedies
# Row 4441 corrected: Horror Movies -> Dramas
# Row 4442 corrected: Cult Movies -> Action & Adventure
# Row 4443 corrected: Thrillers -> Comedies
# Row 4444 corrected: Reality TV -> Comedies
# Row 4445 corrected: Horror Movies -> Dramas
# Row 4446 corrected: Kids' TV -> Comedies
# Row 4447 corrected: TV Comedies -> Stand-Up Comedy
# Row 4448 corrected: Children & Family Movies -> Comedies
# Row 4449 corrected: TV Dramas -> Dramas
# Row 4450 corrected: TV Dramas -> Stand-Up Comedy
# Row 4451 corrected: TV Dramas -> Dramas
# Row 4452 corrected: Romantic Movies -> Comedies
# Row 4453 corrected: Thrillers -> Dramas
# Row 4454 corrected: TV Horror -> Comedies
# Row 4455 corrected: Thrillers -> Action & Adventure
# Row 4456 corrected: TV Comedies -> Dramas
# Row 4458 corrected: Docuseries -> Comedies
# Row 4459 corrected: Romantic Movies -> Dramas
# Row 4460 corrected: Stand-Up Comedy & Talk Shows -> Stand-Up Comedy
# Row 4461 corrected: TV Horror -> British TV Shows
# Row 4462 corrected: Docuseries -> Documentaries
# Row 4463 corrected: Thrillers -> Dramas
# Row 4464 corrected: Cult Movies -> Comedies
# Row 4465 corrected: Sci-Fi & Fantasy -> Comedies
# Row 4466 corrected: Science & Nature TV -> Children & Family Movies
# Row 4467 corrected: Anime Features -> Dramas
# Row 4468 corrected: Documentaries -> Dramas
# Row 4469 corrected: Music & Musicals -> Anime Series
# Row 4470 corrected: Dramas -> Action & Adventure
# Row 4471 corrected: Thrillers -> Dramas
# Row 4472 corrected: TV Comedies -> Dramas
# Row 4473 corrected: Docuseries -> Comedies
# Row 4475 corrected: TV Sci-Fi & Fantasy -> Documentaries
# Row 4476 corrected: TV Dramas -> Crime TV Shows
# Row 4477 corrected: Horror Movies -> Dramas
# Row 4478 corrected: Thrillers -> Kids' TV
# Row 4479 corrected: Romantic Movies -> TV Comedies
# Row 4480 corrected: TV Sci-Fi & Fantasy -> Documentaries
# Row 4481 corrected: Kids' TV -> Action & Adventure
# Row 4482 corrected: Thrillers -> Stand-Up Comedy
# Row 4483 corrected: TV Horror -> International TV Shows
# Row 4484 corrected: Anime Series -> Action & Adventure
# Row 4485 corrected: Sports Movies -> Stand-Up Comedy & Talk Shows
# Row 4487 corrected: Comedies -> International TV Shows
# Row 4489 corrected: TV Comedies -> Kids' TV
# Row 4490 corrected: Sci-Fi & Fantasy -> Movies
# Row 4491 corrected: Anime Series -> Movies
# Row 4492 corrected: Horror Movies -> Children & Family Movies
# Row 4493 corrected: TV Dramas -> Action & Adventure
# Row 4494 corrected: TV Comedies -> Crime TV Shows
# Row 4495 corrected: TV Comedies -> Crime TV Shows
# Row 4496 corrected: Thrillers -> Dramas
# Row 4497 corrected: Stand-Up Comedy & Talk Shows -> Movies
# Row 4498 corrected: Thrillers -> International TV Shows
# Row 4499 corrected: Sports Movies -> Action & Adventure
# Row 4500 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4501 corrected: Horror Movies -> British TV Shows
# Row 4502 corrected: Docuseries -> Dramas
# Row 4503 corrected: Romantic Movies -> Kids' TV
# Row 4504 corrected: Docuseries -> Crime TV Shows
# Row 4505 corrected: TV Comedies -> Stand-Up Comedy
# Row 4506 corrected: Classic & Cult TV -> Dramas
# Row 4507 corrected: Comedies -> Dramas
# Row 4508 corrected: TV Shows -> British TV Shows
# Row 4509 corrected: Anime Series -> Dramas
# Row 4510 corrected: Science & Nature TV -> Horror Movies
# Row 4511 corrected: TV Comedies -> Crime TV Shows
# Row 4512 corrected: Thrillers -> Horror Movies
# Row 4513 corrected: Comedies -> Documentaries
# Row 4514 corrected: Sci-Fi & Fantasy -> Docuseries
# Row 4515 corrected: TV Sci-Fi & Fantasy -> Horror Movies
# Row 4516 corrected: Action & Adventure -> Documentaries
# Row 4517 corrected: Sci-Fi & Fantasy -> TV Comedies
# Row 4518 corrected: Sci-Fi & Fantasy -> TV Dramas
# Row 4519 corrected: Stand-Up Comedy & Talk Shows -> Dramas
# Row 4520 corrected: Docuseries -> Crime TV Shows
# Row 4521 corrected: Sci-Fi & Fantasy -> Docuseries
# Row 4522 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4523 corrected: Sports Movies -> Crime TV Shows
# Row 4524 corrected: Sci-Fi & Fantasy -> Cult Movies
# Row 4525 corrected: TV Comedies -> Stand-Up Comedy
# Row 4526 corrected: Thrillers -> Action & Adventure
# Row 4527 corrected: Comedies -> Kids' TV
# Row 4528 corrected: Sci-Fi & Fantasy -> Horror Movies
# Row 4529 corrected: Horror Movies -> Reality TV
# Row 4530 corrected: TV Dramas -> Docuseries
# Row 4532 corrected: TV Horror -> Horror Movies
# Row 4534 corrected: Science & Nature TV -> Children & Family Movies
# Row 4535 corrected: Sports Movies -> International TV Shows
# Row 4536 corrected: Docuseries -> Anime Series
# Row 4537 corrected: Kids' TV -> Dramas
# Row 4538 corrected: Science & Nature TV -> Horror Movies
# Row 4539 corrected: TV Horror -> Action & Adventure
# Row 4540 corrected: TV Comedies -> Comedies
# Row 4542 corrected: Comedies -> British TV Shows
# Row 4543 corrected: TV Dramas -> Documentaries
# Row 4544 corrected: Independent Movies -> Comedies
# Row 4545 corrected: Stand-Up Comedy & Talk Shows -> Comedies
# Row 4546 corrected: Stand-Up Comedy & Talk Shows -> Comedies
# Row 4547 corrected: Anime Features -> Comedies
# Row 4548 corrected: TV Comedies -> Documentaries
# Row 4549 corrected: Horror Movies -> British TV Shows
# Row 4550 corrected: Thrillers -> International TV Shows
# Row 4551 corrected: Children & Family Movies -> British TV Shows
# Row 4552 corrected: TV Dramas -> Classic Movies
# Row 4553 corrected: Thrillers -> British TV Shows
# Row 4554 corrected: Romantic Movies -> Comedies
# Row 4555 corrected: Thrillers -> Documentaries
# Row 4556 corrected: Comedies -> Action & Adventure
# Row 4557 corrected: TV Thrillers -> Children & Family Movies
# Row 4558 corrected: Romantic Movies -> Horror Movies
# Row 4559 corrected: Music & Musicals -> Action & Adventure
# Row 4560 corrected: Documentaries -> Dramas
# Row 4561 corrected: Thrillers -> Dramas
# Row 4562 corrected: Independent Movies -> Dramas
# Row 4563 corrected: TV Sci-Fi & Fantasy -> International Movies
# Row 4564 corrected: Anime Series -> Dramas
# Row 4565 corrected: Horror Movies -> Comedies
# Row 4566 corrected: TV Comedies -> Dramas
# Row 4567 corrected: TV Horror -> Dramas
# Row 4568 corrected: Romantic Movies -> Comedies
# Row 4569 corrected: Horror Movies -> Dramas
# Row 4570 corrected: TV Comedies -> Romantic TV Shows
# Row 4571 corrected: Romantic Movies -> Action & Adventure
# Row 4572 corrected: TV Comedies -> Comedies
# Row 4573 corrected: Kids' TV -> Action & Adventure
# Row 4574 corrected: Stand-Up Comedy -> Comedies
# Row 4575 corrected: Comedies -> Dramas
# Row 4576 corrected: Horror Movies -> Dramas
# Row 4577 corrected: Anime Features -> Comedies
# Row 4578 corrected: Children & Family Movies -> Action & Adventure
# Row 4579 corrected: Anime Series -> Comedies
# Row 4580 corrected: TV Shows -> International Movies
# Row 4581 corrected: TV Comedies -> Dramas
# Row 4582 corrected: Thrillers -> Comedies
# Row 4583 corrected: Horror Movies -> Comedies
# Row 4584 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4585 corrected: Docuseries -> Comedies
# Row 4586 corrected: TV Comedies -> Action & Adventure
# Row 4587 corrected: Classic Movies -> Action & Adventure
# Row 4588 corrected: Thrillers -> Comedies
# Row 4589 corrected: Horror Movies -> Children & Family Movies
# Row 4590 corrected: Sci-Fi & Fantasy -> Children & Family Movies
# Row 4591 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4592 corrected: Anime Series -> Action & Adventure
# Row 4593 corrected: Stand-Up Comedy -> Dramas
# Row 4594 corrected: TV Comedies -> Comedies
# Row 4595 corrected: Sports Movies -> Action & Adventure
# Row 4596 corrected: Dramas -> Comedies
# Row 4597 corrected: Dramas -> Action & Adventure
# Row 4598 corrected: TV Comedies -> Horror Movies
# Row 4599 corrected: Docuseries -> Comedies
# Row 4600 corrected: Stand-Up Comedy -> Action & Adventure
# Row 4601 corrected: TV Horror -> Action & Adventure
# Row 4602 corrected: Thrillers -> Comedies
# Row 4603 corrected: Action & Adventure -> Comedies
# Row 4604 corrected: Science & Nature TV -> Reality TV
# Row 4605 corrected: LGBTQ Movies -> Action & Adventure
# Row 4607 corrected: TV Shows -> Comedies
# Row 4608 corrected: Romantic Movies -> British TV Shows
# Row 4609 corrected: TV Sci-Fi & Fantasy -> Action & Adventure
# Row 4610 corrected: Faith & Spirituality -> Dramas
# Row 4611 corrected: TV Action & Adventure -> Action & Adventure
# Row 4612 corrected: Sports Movies -> Comedies
# Row 4613 corrected: Cult Movies -> Dramas
# Row 4614 corrected: Korean TV Shows -> Comedies
# Row 4615 corrected: Anime Series -> Dramas
# Row 4616 corrected: Thrillers -> Children & Family Movies
# Row 4617 corrected: TV Dramas -> Dramas
# Row 4618 corrected: Docuseries -> Action & Adventure
# Row 4619 corrected: Horror Movies -> Action & Adventure
# Row 4620 corrected: TV Comedies -> Documentaries
# Row 4621 corrected: Horror Movies -> International TV Shows
# Row 4622 corrected: Anime Series -> Kids' TV
# Row 4623 corrected: Dramas -> Kids' TV
# Row 4624 corrected: Thrillers -> Horror Movies
# Row 4625 corrected: TV Comedies -> Documentaries
# Row 4626 corrected: Docuseries -> Independent Movies
# Row 4627 corrected: TV Comedies -> Reality TV
# Row 4628 corrected: TV Dramas -> Anime Series
# Row 4629 corrected: Music & Musicals -> TV Comedies
# Row 4630 corrected: Kids' TV -> Documentaries
# Row 4631 corrected: Comedies -> Stand-Up Comedy
# Row 4632 corrected: Thrillers -> Crime TV Shows
# Row 4633 corrected: Independent Movies -> Anime Series
# Row 4634 corrected: Dramas -> Kids' TV
# Row 4635 corrected: Docuseries -> Crime TV Shows
# Row 4636 corrected: Kids' TV -> Crime TV Shows
# Row 4637 corrected: TV Comedies -> Docuseries
# Row 4638 corrected: TV Comedies -> Crime TV Shows
# Row 4639 corrected: TV Comedies -> Stand-Up Comedy & Talk Shows
# Row 4640 corrected: Anime Features -> Kids' TV
# Row 4641 corrected: Cult Movies -> Dramas
# Row 4642 corrected: Anime Features -> Comedies
# Row 4643 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 4644 corrected: Thrillers -> Documentaries
# Row 4645 corrected: TV Horror -> International TV Shows
# Row 4646 corrected: TV Comedies -> Dramas
# Row 4647 corrected: International TV Shows -> Stand-Up Comedy & Talk Shows
# Row 4648 corrected: TV Action & Adventure -> Docuseries
# Row 4650 corrected: Music & Musicals -> International TV Shows
# Row 4651 corrected: Horror Movies -> Kids' TV
# Row 4652 corrected: TV Comedies -> Kids' TV
# Row 4653 corrected: TV Dramas -> Documentaries
# Row 4654 corrected: LGBTQ Movies -> Docuseries
# Row 4655 corrected: TV Comedies -> Crime TV Shows
# Row 4656 corrected: Action & Adventure -> Children & Family Movies
# Row 4657 corrected: Romantic Movies -> Comedies
# Row 4658 corrected: Sports Movies -> Kids' TV
# Row 4659 corrected: Documentaries -> Dramas
# Row 4660 corrected: Kids' TV -> Comedies
# Row 4661 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4662 corrected: Sci-Fi & Fantasy -> Crime TV Shows
# Row 4663 corrected: Classic Movies -> Crime TV Shows
# Row 4664 corrected: Thrillers -> Crime TV Shows
# Row 4665 corrected: TV Dramas -> Dramas
# Row 4666 corrected: Thrillers -> Dramas
# Row 4667 corrected: Kids' TV -> Dramas
# Row 4668 corrected: Stand-Up Comedy & Talk Shows -> Dramas
# Row 4669 corrected: Docuseries -> Dramas
# Row 4670 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 4671 corrected: Reality TV -> Dramas
# Row 4672 corrected: Classic Movies -> International TV Shows
# Row 4674 corrected: Stand-Up Comedy -> Stand-Up Comedy & Talk Shows
# Row 4675 corrected: Thrillers -> Comedies
# Row 4676 corrected: Stand-Up Comedy -> Reality TV
# Row 4677 corrected: TV Comedies -> Reality TV
# Row 4678 corrected: Docuseries -> Crime TV Shows
# Row 4679 corrected: TV Dramas -> Action & Adventure
# Row 4680 corrected: Stand-Up Comedy -> Comedies
# Row 4681 corrected: Dramas -> Action & Adventure
# Row 4682 corrected: Comedies -> Docuseries
# Row 4683 corrected: Anime Series -> Stand-Up Comedy
# Row 4684 corrected: Reality TV -> Stand-Up Comedy
# Row 4685 corrected: TV Comedies -> International TV Shows
# Row 4686 corrected: TV Comedies -> Comedies
# Row 4687 corrected: Sci-Fi & Fantasy -> International TV Shows
# Row 4688 corrected: Anime Features -> Comedies
# Row 4689 corrected: Independent Movies -> British TV Shows
# Row 4690 corrected: Horror Movies -> Comedies
# Row 4691 corrected: Sci-Fi & Fantasy -> Action & Adventure
# Row 4692 corrected: Romantic Movies -> Dramas
# Row 4693 corrected: Spanish-Language TV Shows -> Dramas
# Row 4694 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4695 corrected: Horror Movies -> Comedies
# Row 4696 corrected: Sports Movies -> Reality TV
# Row 4697 corrected: Classic Movies -> Comedies
# Row 4698 corrected: TV Sci-Fi & Fantasy -> Comedies
# Row 4699 corrected: Comedies -> Stand-Up Comedy
# Row 4700 corrected: TV Horror -> Dramas
# Row 4701 corrected: Cult Movies -> Comedies
# Row 4702 corrected: TV Shows -> Docuseries
# Row 4703 corrected: Anime Features -> Docuseries
# Row 4704 corrected: Anime Series -> TV Comedies
# Row 4705 corrected: Kids' TV -> Dramas
# Row 4706 corrected: Anime Series -> Comedies
# Row 4707 corrected: Sci-Fi & Fantasy -> Documentaries
# Row 4708 corrected: TV Comedies -> Dramas
# Row 4709 corrected: Action & Adventure -> TV Dramas
# Row 4710 corrected: TV Sci-Fi & Fantasy -> International TV Shows
# Row 4711 corrected: TV Horror -> International TV Shows
# Row 4712 corrected: Anime Series -> Comedies
# Row 4713 corrected: Romantic Movies -> Action & Adventure
# Row 4714 corrected: Anime Features -> Comedies
# Row 4715 corrected: Independent Movies -> Anime Features
# Row 4716 corrected: Spanish-Language TV Shows -> Crime TV Shows
# Row 4717 corrected: TV Comedies -> Kids' TV
# Row 4718 corrected: Docuseries -> Comedies
# Row 4719 corrected: Stand-Up Comedy -> Dramas
# Row 4720 corrected: TV Horror -> Children & Family Movies
# Row 4721 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4722 corrected: Reality TV -> Dramas
# Row 4723 corrected: TV Sci-Fi & Fantasy -> Dramas
# Row 4724 corrected: Kids' TV -> Dramas
# Row 4725 corrected: TV Dramas -> Dramas
# Row 4726 corrected: Comedies -> Action & Adventure
# Row 4727 corrected: Stand-Up Comedy -> Comedies
# ...
# Row 8411 corrected: nan -> British TV Shows
# Row 8412 corrected: nan -> Documentaries
# Row 8413 corrected: nan -> Action & Adventure
# Row 8414 corrected: nan -> Action & Adventure
# Row 8415 corrected: nan -> Action & Adventure
# Row 8416 corrected: nan -> Action & Adventure
# Row 8417 corrected: nan -> Documentaries
# Row 8418 corrected: nan -> Dramas
# Row 8419 corrected: nan -> Classic Movies
# Row 8420 corrected: nan -> Comedies
# Row 8421 corrected: nan -> TV Dramas
# Row 8422 corrected: nan -> Docuseries
# Row 8423 corrected: nan -> Kids' TV
# Row 8424 corrected: nan -> International TV Shows
# Row 8425 corrected: nan -> Dramas
# Row 8426 corrected: nan -> Horror Movies
# Row 8427 corrected: nan -> Dramas
# Row 8428 corrected: nan -> Docuseries
# Row 8429 corrected: nan -> International TV Shows
# Row 8430 corrected: nan -> Children & Family Movies
# Row 8431 corrected: nan -> British TV Shows
# Row 8432 corrected: nan -> Dramas
# Row 8433 corrected: nan -> Comedies
# Row 8434 corrected: nan -> Comedies
# Row 8435 corrected: nan -> Classic Movies
# Row 8436 corrected: nan -> Classic Movies
# Row 8437 corrected: nan -> Stand-Up Comedy & Talk Shows
# Row 8438 corrected: nan -> Comedies
# Row 8439 corrected: nan -> Docuseries
# Row 8440 corrected: nan -> Documentaries
# Row 8441 corrected: nan -> Children & Family Movies
# Row 8442 corrected: nan -> TV Comedies
# Row 8443 corrected: nan -> Comedies
# Row 8444 corrected: nan -> Comedies
# Row 8445 corrected: nan -> Action & Adventure
# Row 8446 corrected: nan -> Action & Adventure
# Row 8447 corrected: nan -> Dramas
# Row 8448 corrected: nan -> Action & Adventure
# Row 8449 corrected: nan -> Dramas
# Row 8450 corrected: nan -> Documentaries
# Row 8451 corrected: nan -> Comedies
# Row 8452 corrected: nan -> Dramas
# Row 8453 corrected: nan -> Action & Adventure
# Row 8454 corrected: nan -> Children & Family Movies
# Row 8455 corrected: nan -> Children & Family Movies
# Row 8456 corrected: nan -> Dramas
# Row 8457 corrected: nan -> Children & Family Movies
# Row 8458 corrected: nan -> Dramas
# Row 8459 corrected: nan -> Dramas
# Row 8460 corrected: nan -> Comedies
# Row 8461 corrected: nan -> Children & Family Movies
# Row 8462 corrected: nan -> Documentaries
# Row 8463 corrected: nan -> Comedies
# Row 8464 corrected: nan -> Action & Adventure
# Row 8465 corrected: nan -> Comedies
# Row 8466 corrected: nan -> Children & Family Movies
# Row 8467 corrected: nan -> Action & Adventure
# Row 8468 corrected: nan -> Documentaries
# Row 8469 corrected: nan -> Dramas
# Row 8470 corrected: nan -> Documentaries
# Row 8471 corrected: nan -> Docuseries
# Row 8472 corrected: nan -> Children & Family Movies
# Row 8473 corrected: nan -> Dramas
# Row 8474 corrected: nan -> Reality TV
# Row 8475 corrected: nan -> Documentaries
# Row 8476 corrected: nan -> British TV Shows
# Row 8477 corrected: nan -> Documentaries
# Row 8478 corrected: nan -> Documentaries
# Row 8479 corrected: nan -> Documentaries
# Row 8480 corrected: nan -> Dramas
# Row 8481 corrected: nan -> Dramas
# Row 8482 corrected: nan -> International TV Shows
# Row 8483 corrected: nan -> Horror Movies
# Row 8484 corrected: nan -> Horror Movies
# Row 8485 corrected: nan -> Dramas
# Row 8486 corrected: nan -> Horror Movies
# Row 8487 corrected: nan -> Dramas
# Row 8488 corrected: nan -> Dramas
# Row 8489 corrected: nan -> Action & Adventure
# Row 8490 corrected: nan -> International TV Shows
# Row 8491 corrected: nan -> Documentaries
# Row 8492 corrected: nan -> Thrillers
# Row 8493 corrected: nan -> International Movies
# Row 8494 corrected: nan -> Comedies
# Row 8495 corrected: nan -> Dramas
# Row 8496 corrected: nan -> Dramas
# Row 8497 corrected: nan -> Comedies
# Row 8498 corrected: nan -> Dramas
# Row 8499 corrected: nan -> Dramas
# Row 8500 corrected: nan -> Documentaries
# Row 8501 corrected: nan -> Children & Family Movies
# Row 8502 corrected: nan -> Documentaries
# Row 8503 corrected: nan -> Docuseries
# Row 8504 corrected: nan -> Comedies
# Row 8505 corrected: nan -> Dramas
# Row 8506 corrected: nan -> Classic Movies
# Row 8507 corrected: nan -> Sci-Fi & Fantasy
# Row 8508 corrected: nan -> Horror Movies
# Row 8509 corrected: nan -> Dramas
# Row 8510 corrected: nan -> Crime TV Shows
# Row 8511 corrected: nan -> Dramas
# Row 8512 corrected: nan -> Action & Adventure
# Row 8513 corrected: nan -> Dramas
# Row 8514 corrected: nan -> Dramas
# Row 8515 corrected: nan -> Action & Adventure
# Row 8516 corrected: nan -> Documentaries
# Row 8517 corrected: nan -> Dramas
# Row 8518 corrected: nan -> Docuseries
# Row 8519 corrected: nan -> Docuseries
# Row 8520 corrected: nan -> Thrillers
# Row 8521 corrected: nan -> Documentaries
# Row 8522 corrected: nan -> Horror Movies
# Row 8523 corrected: nan -> Kids' TV
# Row 8524 corrected: nan -> Documentaries
# Row 8525 corrected: nan -> Action & Adventure
# Row 8526 corrected: nan -> Dramas
# Row 8527 corrected: nan -> Cult Movies
# Row 8528 corrected: nan -> Dramas
# Row 8529 corrected: nan -> Comedies
# Row 8530 corrected: nan -> Documentaries
# Row 8531 corrected: nan -> Action & Adventure
# Row 8532 corrected: nan -> Dramas
# Row 8533 corrected: nan -> Crime TV Shows
# Row 8534 corrected: nan -> Dramas
# Row 8535 corrected: nan -> Thrillers
# Row 8536 corrected: nan -> Comedies
# Row 8537 corrected: nan -> Thrillers
# Row 8538 corrected: nan -> Documentaries
# Row 8539 corrected: nan -> TV Dramas
# Row 8540 corrected: nan -> Action & Adventure
# Row 8541 corrected: nan -> Classic & Cult TV
# Row 8542 corrected: nan -> Comedies
# Row 8543 corrected: nan -> Horror Movies
# Row 8544 corrected: nan -> International TV Shows
# Row 8545 corrected: nan -> Docuseries
# Row 8546 corrected: nan -> Dramas
# Row 8547 corrected: nan -> Documentaries
# Row 8548 corrected: nan -> Horror Movies
# Row 8549 corrected: nan -> Docuseries
# Row 8550 corrected: nan -> Action & Adventure
# Row 8551 corrected: nan -> Docuseries
# Row 8552 corrected: nan -> Dramas
# Row 8553 corrected: nan -> Children & Family Movies
# Row 8554 corrected: nan -> Comedies
# Row 8555 corrected: nan -> Horror Movies
# Row 8556 corrected: nan -> Comedies
# Row 8557 corrected: nan -> TV Dramas
# Row 8558 corrected: nan -> Horror Movies
# Row 8559 corrected: nan -> Horror Movies
# Row 8560 corrected: nan -> International TV Shows
# Row 8561 corrected: nan -> Documentaries
# Row 8562 corrected: nan -> Comedies
# Row 8563 corrected: nan -> Dramas
# Row 8564 corrected: nan -> Action & Adventure
# Row 8565 corrected: nan -> Documentaries
# Row 8566 corrected: nan -> Thrillers
# Row 8567 corrected: nan -> International TV Shows
# Row 8568 corrected: nan -> Comedies
# Row 8569 corrected: nan -> Action & Adventure
# Row 8570 corrected: nan -> Documentaries
# Row 8571 corrected: nan -> Dramas
# Row 8572 corrected: nan -> Documentaries
# Row 8573 corrected: nan -> Documentaries
# Row 8574 corrected: nan -> International TV Shows
# Row 8575 corrected: nan -> International TV Shows
# Row 8576 corrected: nan -> Comedies
# Row 8577 corrected: nan -> Documentaries
# Row 8578 corrected: nan -> Dramas
# Row 8579 corrected: nan -> Action & Adventure
# Row 8580 corrected: nan -> Action & Adventure
# Row 8581 corrected: nan -> Children & Family Movies
# Row 8582 corrected: nan -> Dramas
# Row 8583 corrected: nan -> Dramas
# Row 8584 corrected: nan -> Action & Adventure
# Row 8585 corrected: nan -> Comedies
# Row 8586 corrected: nan -> Dramas
# Row 8587 corrected: nan -> Classic Movies
# Row 8588 corrected: nan -> Crime TV Shows
# Row 8589 corrected: nan -> Dramas
# Row 8590 corrected: nan -> Dramas
# Row 8591 corrected: nan -> Comedies
# Row 8592 corrected: nan -> International TV Shows
# Row 8593 corrected: nan -> Crime TV Shows
# Row 8594 corrected: nan -> Children & Family Movies
# Row 8595 corrected: nan -> Dramas
# Row 8596 corrected: nan -> Kids' TV
# Row 8597 corrected: nan -> Documentaries
# Row 8598 corrected: nan -> Comedies
# Row 8599 corrected: nan -> British TV Shows
# Row 8600 corrected: nan -> Kids' TV
# Row 8601 corrected: nan -> Documentaries
# Row 8602 corrected: nan -> Children & Family Movies
# Row 8603 corrected: nan -> Action & Adventure
# Row 8604 corrected: nan -> British TV Shows
# Row 8605 corrected: nan -> Reality TV
# Row 8606 corrected: nan -> Dramas
# Row 8607 corrected: nan -> Comedies
# Row 8608 corrected: nan -> Comedies
# Row 8609 corrected: nan -> International TV Shows
# Row 8610 corrected: nan -> Action & Adventure
# Row 8611 corrected: nan -> Dramas
# Row 8612 corrected: nan -> Horror Movies
# Row 8613 corrected: nan -> Action & Adventure
# Row 8614 corrected: nan -> Comedies
# Row 8615 corrected: nan -> Dramas
# Row 8616 corrected: nan -> Sci-Fi & Fantasy
# Row 8617 corrected: nan -> Dramas
# Row 8618 corrected: nan -> Comedies
# Row 8619 corrected: nan -> Documentaries
# Row 8620 corrected: nan -> Documentaries
# Row 8621 corrected: nan -> Comedies
# Row 8622 corrected: nan -> Comedies
# Row 8623 corrected: nan -> Comedies
# Row 8624 corrected: nan -> Comedies
# Row 8625 corrected: nan -> Comedies
# Row 8626 corrected: nan -> Action & Adventure
# Row 8627 corrected: nan -> Dramas
# Row 8628 corrected: nan -> Comedies
# Row 8629 corrected: nan -> Action & Adventure
# Row 8630 corrected: nan -> International Movies
# Row 8631 corrected: nan -> Documentaries
# Row 8632 corrected: nan -> Documentaries
# Row 8633 corrected: nan -> International TV Shows
# Row 8634 corrected: nan -> Action & Adventure
# Row 8635 corrected: nan -> Classic Movies
# Row 8636 corrected: nan -> Dramas
# Row 8637 corrected: nan -> Dramas
# Row 8638 corrected: nan -> Comedies
# Row 8639 corrected: nan -> Dramas
# Row 8640 corrected: nan -> Classic Movies
# Row 8641 corrected: nan -> Children & Family Movies
# Row 8642 corrected: nan -> Horror Movies
# Row 8643 corrected: nan -> Documentaries
# Row 8644 corrected: nan -> Classic & Cult TV
# Row 8645 corrected: nan -> Horror Movies
# Row 8646 corrected: nan -> British TV Shows
# Row 8647 corrected: nan -> Dramas
# Row 8648 corrected: nan -> Thrillers
# Row 8649 corrected: nan -> Dramas
# Row 8650 corrected: nan -> Documentaries
# Row 8651 corrected: nan -> Documentaries
# Row 8652 corrected: nan -> Dramas
# Row 8653 corrected: nan -> International TV Shows
# Row 8654 corrected: nan -> Dramas
# Row 8655 corrected: nan -> Children & Family Movies
# Row 8656 corrected: nan -> Documentaries
# Row 8657 corrected: nan -> Action & Adventure
# Row 8658 corrected: nan -> Dramas
# Row 8659 corrected: nan -> Action & Adventure
# Row 8660 corrected: nan -> Classic Movies
# Row 8661 corrected: nan -> Comedies
# Row 8662 corrected: nan -> Dramas
# Row 8663 corrected: nan -> International Movies
# Row 8664 corrected: nan -> Comedies
# Row 8665 corrected: nan -> Dramas
# Row 8666 corrected: nan -> Action & Adventure
# Row 8667 corrected: nan -> Action & Adventure
# Row 8668 corrected: nan -> Action & Adventure
# Row 8669 corrected: nan -> Kids' TV
# Row 8670 corrected: nan -> Action & Adventure
# Row 8671 corrected: nan -> Action & Adventure
# Row 8672 corrected: nan -> Comedies
# Row 8673 corrected: nan -> Documentaries
# Row 8674 corrected: nan -> Dramas
# Row 8675 corrected: nan -> Dramas
# Row 8676 corrected: nan -> Action & Adventure
# Row 8677 corrected: nan -> Documentaries
# Row 8678 corrected: nan -> Dramas
# Row 8679 corrected: nan -> Kids' TV
# Row 8680 corrected: nan -> Dramas
# Row 8681 corrected: nan -> Dramas
# Row 8682 corrected: nan -> Comedies
# Row 8683 corrected: nan -> Dramas
# Row 8684 corrected: nan -> Kids' TV
# Row 8685 corrected: nan -> Dramas
# Row 8686 corrected: nan -> Action & Adventure
# Row 8687 corrected: nan -> Action & Adventure
# Row 8688 corrected: nan -> Dramas
# Row 8689 corrected: nan -> Comedies
# Row 8690 corrected: nan -> International TV Shows
# Row 8691 corrected: nan -> Dramas
# Row 8692 corrected: nan -> Documentaries
# Row 8693 corrected: nan -> Dramas
# Row 8694 corrected: nan -> Action & Adventure
# Row 8695 corrected: nan -> Comedies
# Row 8696 corrected: nan -> Dramas
# Row 8697 corrected: nan -> Action & Adventure
# Row 8698 corrected: nan -> Horror Movies
# Row 8699 corrected: nan -> Comedies
# Row 8700 corrected: nan -> Docuseries
# Row 8701 corrected: nan -> Documentaries
# Row 8702 corrected: nan -> Documentaries
# Row 8703 corrected: nan -> Dramas
# Row 8704 corrected: nan -> Thrillers
# Row 8705 corrected: nan -> Comedies
# Row 8706 corrected: nan -> Dramas
# Row 8707 corrected: nan -> Documentaries
# Row 8708 corrected: nan -> Comedies
# Row 8709 corrected: nan -> Dramas
# Row 8710 corrected: nan -> TV Comedies
# Row 8711 corrected: nan -> Dramas
# Row 8712 corrected: nan -> British TV Shows
# Row 8713 corrected: nan -> Comedies
# Row 8714 corrected: nan -> Children & Family Movies
# Row 8715 corrected: nan -> Dramas
# Row 8716 corrected: nan -> Comedies
# Row 8717 corrected: nan -> Classic Movies
# Row 8718 corrected: nan -> Documentaries
# Row 8719 corrected: nan -> Comedies
# Row 8720 corrected: nan -> International TV Shows
# Row 8721 corrected: nan -> International TV Shows
# Row 8722 corrected: nan -> Horror Movies
# Row 8723 corrected: nan -> Documentaries
# Row 8724 corrected: nan -> Dramas
# Row 8725 corrected: nan -> Dramas
# Row 8726 corrected: nan -> TV Dramas
# Row 8727 corrected: nan -> Documentaries
# Row 8728 corrected: nan -> Documentaries
# Row 8729 corrected: nan -> Action & Adventure
# Row 8730 corrected: nan -> Comedies
# Row 8731 corrected: nan -> Comedies
# Row 8732 corrected: nan -> Sci-Fi & Fantasy
# Row 8733 corrected: nan -> Comedies
# Row 8734 corrected: nan -> Documentaries
# Row 8735 corrected: nan -> Classic Movies
# Row 8736 corrected: nan -> International TV Shows
# Row 8737 corrected: nan -> Documentaries
# Row 8738 corrected: nan -> Documentaries
# Row 8739 corrected: nan -> Documentaries
# Row 8740 corrected: nan -> British TV Shows
# Row 8741 corrected: nan -> British TV Shows
# Row 8742 corrected: nan -> Action & Adventure
# Row 8743 corrected: nan -> Dramas
# Row 8744 corrected: nan -> Documentaries
# Row 8745 corrected: nan -> Children & Family Movies
# Row 8746 corrected: nan -> Documentaries
# Row 8747 corrected: nan -> Reality TV
# Row 8748 corrected: nan -> Classic Movies
# Row 8749 corrected: nan -> International TV Shows
# Row 8750 corrected: nan -> Dramas
# Row 8751 corrected: nan -> Comedies
# Row 8752 corrected: nan -> Children & Family Movies
# Row 8753 corrected: nan -> Dramas
# Row 8754 corrected: nan -> Dramas
# Row 8755 corrected: nan -> Crime TV Shows
# Row 8756 corrected: nan -> Documentaries
# Row 8757 corrected: nan -> Action & Adventure
# Row 8758 corrected: nan -> British TV Shows
# Row 8759 corrected: nan -> Movies
# Row 8760 corrected: nan -> Horror Movies
# Row 8761 corrected: nan -> Comedies
# Row 8762 corrected: nan -> Dramas
# Row 8763 corrected: nan -> Documentaries
# Row 8764 corrected: nan -> Action & Adventure
# Row 8765 corrected: nan -> Horror Movies
# Row 8766 corrected: nan -> Action & Adventure
# Row 8767 corrected: nan -> Action & Adventure
# Row 8768 corrected: nan -> Dramas
# Row 8769 corrected: nan -> Dramas
# Row 8770 corrected: nan -> Dramas
# Row 8771 corrected: nan -> Dramas
# Row 8772 corrected: nan -> Action & Adventure
# Row 8773 corrected: nan -> Comedies
# Row 8774 corrected: nan -> Dramas
# Row 8775 corrected: nan -> International TV Shows
# Row 8776 corrected: nan -> Children & Family Movies
# Row 8777 corrected: nan -> International Movies
# Row 8778 corrected: nan -> International Movies
# Row 8779 corrected: nan -> International Movies
# Row 8780 corrected: nan -> Anime Series
# Row 8781 corrected: nan -> Anime Features
# Row 8782 corrected: nan -> Comedies
# Row 8783 corrected: nan -> Kids' TV
# Row 8784 corrected: nan -> Children & Family Movies
# Row 8785 corrected: nan -> Kids' TV
# Row 8786 corrected: nan -> Children & Family Movies
# Row 8787 corrected: nan -> Comedies
# Row 8788 corrected: nan -> Dramas
# Row 8789 corrected: nan -> Comedies
# Row 8790 corrected: nan -> Action & Adventure
# Row 8791 corrected: nan -> Comedies
# Row 8792 corrected: nan -> Action & Adventure
# Row 8793 corrected: nan -> Children & Family Movies
# Row 8794 corrected: nan -> Dramas
# Row 8795 corrected: nan -> Anime Series
# Row 8796 corrected: nan -> International TV Shows
# Row 8797 corrected: nan -> Kids' TV
# Row 8798 corrected: nan -> Comedies
# Row 8799 corrected: nan -> Dramas
# Row 8800 corrected: nan -> International TV Shows
# Row 8801 corrected: nan -> Dramas
# Row 8802 corrected: nan -> Cult Movies
# Row 8803 corrected: nan -> Kids' TV
# Row 8804 corrected: nan -> Comedies
# Row 8805 corrected: nan -> Children & Family Movies
# Row 8806 corrected: nan -> Dramas
