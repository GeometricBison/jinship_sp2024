# %%
# !pip install datasets
# !pip install bertopic
# !pip install langchain
# !pip install ctransformers
# !pip install nltk
# Out:
# Requirement already satisfied: datasets in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (2.17.1)
# Requirement already satisfied: filelock in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: bertopic in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (0.16.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: hdbscan>=0.8.29 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (2.2.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (1.4.1.post1)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (4.66.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (2.4.0)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from bertopic) (5.19.0)
# Requirement already satisfied: cython<3,>=0.27 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (0.29.37)
# Requirement already satisfied: scipy>=1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.12.0)
# Requirement already satisfied: joblib>=1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.38.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.2.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (10.2.0)
# Requirement already satisfied: colorama in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.51.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.59.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.5.11)
# Requirement already satisfied: filelock in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.10.0)
# Requirement already satisfied: requests in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.42.0)
# Requirement already satisfied: six>=1.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: langchain in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (0.1.9)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (1.4.51)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.21 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (0.0.24)
# Requirement already satisfied: langchain-core<0.2,>=0.1.26 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (0.1.26)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (0.1.9)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (2.6.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain-core<0.2,>=0.1.26->langchain) (4.3.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langchain-core<0.2,>=0.1.26->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.26->langchain) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: ctransformers in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (0.2.27)
# Requirement already satisfied: huggingface-hub in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from ctransformers) (0.20.3)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (2023.10.0)
# Requirement already satisfied: requests in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: colorama in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->ctransformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub->ctransformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from requests->huggingface-hub->ctransformers) (2024.2.2)
# Requirement already satisfied: nltk in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\mukhe\uiuc\disruptionlab\topicmodelingenv\lib\site-packages (from click->nltk) (0.4.6)

# %%
from datasets import load_dataset
from bertopic import BERTopic
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

dataset = load_dataset("hugginglearners/netflix-shows", split="train")

# %%
topic_model = BERTopic(nr_topics=20)
topics, probabilities = topic_model.fit_transform(dataset['description'])

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                          Name  \
# 0      -1   4708                              -1_the_to_and_of
# 1       0    779                    0_and_the_standup_comedian
# 2       1    557                         1_their_to_and_school
# 3       2    428                              2_his_her_to_and
# 4       3    427                               3_of_to_the_his
# 5       4    304                                4_the_of_to_in
# 6       5    264                            5_the_to_bheem_his
# 7       6    261                        6_and_christmas_the_to
# 8       7    209                               7_war_the_of_to
# 9       8    204                            8_and_the_music_of
# 10      9    145                         9_soccer_the_his_team
# 11     10    135                    10_the_of_documentary_drug
# 12     11    131                          11_chef_food_and_the
# 13     12     68           12_doctor_patients_hospital_doctors
# 14     13     43               13_shark_the_mermaid_underwater
# 15     14     35      14_contestants_competition_prize_compete
# 16     15     34  15_political_politician_president_corruption
# 17     16     34                        16_the_racing_cars_bus
# 18     17     28                     17_missing_her_woman_town
# 19     18     13               18_russian_revolution_early_the
#
#                                        Representation  \
# 0     [the, to, and, of, in, his, her, with, an, for]
# 1   [and, the, standup, comedian, in, of, comedy, ...
# 2   [their, to, and, school, of, the, for, in, hig...
# 3    [his, her, to, and, with, an, in, the, when, of]
# 4   [of, to, the, his, detective, in, murder, an, ...
# 5   [the, of, to, in, and, by, her, their, haunted...
# 6   [the, to, bheem, his, and, of, rangers, martia...
# 7   [and, christmas, the, to, of, with, friends, s...
# 8   [war, the, of, to, agent, terrorist, in, cia, ...
# 9   [and, the, music, of, this, band, dancer, danc...
# 10  [soccer, the, his, team, player, of, football,...
# 11  [the, of, documentary, drug, this, and, in, to...
# 12  [chef, food, and, the, chefs, cooking, of, to,...
# 13  [doctor, patients, hospital, doctors, cancer, ...
# 14  [shark, the, mermaid, underwater, octonauts, s...
# 15  [contestants, competition, prize, compete, sho...
# 16  [political, politician, president, corruption,...
# 17  [the, racing, cars, bus, train, and, in, drive...
# 18  [missing, her, woman, town, husband, in, repor...
# 19  [russian, revolution, early, the, petersburg, ...
#
#                                   Representative_Docs
# 0   [Overtaken by the death of her beloved, a grie...
# 1   [Chris Rock takes the stage in Brooklyn for a ...
# 2   [Four friends shake up their lives when they m...
# 3   [After his father's passing, a teenager sets o...
# 4   [An ex-con is just getting his life back on tr...
# 5   [After losing their first child in an accident...
# 6   [When Dholakpur’s princess is kidnapped, Bheem...
# 7   [A new pack of Pup Star pooches stumbles upon ...
# 8   [During World War II, British forces launch an...
# 9   [From child prodigy to iconic music producer, ...
# 10  [A young soccer player sets out to prove he ca...
# 11  [Activists around the world fight injustice an...
# 12  [A female food blogger is hired as a personal ...
# 13  [Four doctors at New York's storied Lenox Hill...
# 14  [Four years after the last deadly shark attack...
# 15  [In this karaoke competition hosted by Palina ...
# 16  [The personal barber to the president, as well...
# 17  [Life in the garage swerves off track for a NA...
# 18  [Multiple women report their husbands as missi...
# 19  [Starting in 1881, this film describes how the...

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stopwords.append('the')
stopwords.append('and')
stopwords.append('to')
stopwords.append('of')
stopwords.append('in')
stopwords.append('with')
stopwords.append('an')
stopwords.append('The')
stopwords.append('And')
stopwords.append('To')
stopwords.append('Of')
stopwords.append('In')
stopwords.append('With')
stopwords.append('An')
stopwords.append('A')
stopwords.append('As')
stopwords.append('as')

descriptions = dataset['description']

def remove_stopwords(text):
    output= ' '.join([i for i in text.split() if i not in stopwords])
    return output

processed_descriptions = [remove_stopwords(text) for text in descriptions]
processed_descriptions[:10]
# Out:
# ['father nears end life, filmmaker Kirsten Johnson stages death inventive comical ways help face inevitable.',
#  'After crossing paths party, Cape Town teen sets prove whether private-school swimming star sister abducted birth.',
#  'protect family powerful drug lord, skilled thief Mehdi expert team robbers pulled violent deadly turf war.',
#  'Feuds, flirtations toilet talk go among incarcerated women Orleans Justice Center New Orleans gritty reality series.',
#  'city coaching centers known train India’s finest collegiate minds, earnest unexceptional student friends navigate campus life.',
#  'arrival charismatic young priest brings glorious miracles, ominous mysteries renewed religious fervor dying town desperate believe.',
#  "Equestria's divided. But bright-eyed hero believes Earth Ponies, Pegasi Unicorns pals — and, hoof heart, she’s determined prove it.",
#  'On photo shoot Ghana, American model slips back time, becomes enslaved plantation bears witness agony ancestral past.',
#  "talented batch amateur bakers face 10-week competition, whipping best dishes hopes named U.K.'s best.",
#  "woman adjusting life loss contends feisty bird that's taken garden — husband who's struggling find way forward."]

# %%
updated_topic_model = BERTopic(nr_topics=20)
topics, probabilities = updated_topic_model.fit_transform(processed_descriptions)
updated_topic_model.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1   4464                   -1_life_young_when_love
# 1       0    998                 0_murder_crime_police_cop
# 2       1    983         1_standup_comedian_comedy_special
# 3       2    506             2_school_high_student_friends
# 4       3    457               3_father_family_woman_young
# 5       4    267                  4_earth_space_planet_sea
# 6       5    209             5_christmas_dog_holiday_santa
# 7       6    174              6_soccer_team_prize_football
# 8       7    161                 7_bheem_rangers_save_evil
# 9       8    109                 8_chef_food_cooking_chefs
# 10      9    107                 9_nazi_war_ii_documentary
# 11     10     90        10_cancer_hospital_doctor_patients
# 12     11     87                  11_martial_arts_boxer_fu
# 13     12     66              12_drug_mexico_mexican_pablo
# 14     13     48    13_missing_disappearance_police_search
# 15     14     23    14_politician_political_vote_candidate
# 16     15     18        15_lebanese_beirut_lebanons_syrian
# 17     16     14           16_elizabeth_queen_dianas_royal
# 18     17     13  17_marijuana_smokers_california_hardcore
# 19     18     13  18_russian_revolution_petersburg_turkish
#
#                                        Representation  \
# 0   [life, young, when, love, new, family, two, fr...
# 1   [murder, crime, police, cop, detective, when, ...
# 2   [standup, comedian, comedy, special, comic, do...
# 3   [school, high, student, friends, students, col...
# 4   [father, family, woman, young, single, man, wh...
# 5   [earth, space, planet, sea, crew, science, sci...
# 6   [christmas, dog, holiday, santa, friends, fun,...
# 7   [soccer, team, prize, football, compete, athle...
# 8   [bheem, rangers, save, evil, powers, when, sup...
# 9   [chef, food, cooking, chefs, dishes, culinary,...
# 10  [nazi, war, ii, documentary, this, world, nazi...
# 11  [cancer, hospital, doctor, patients, medical, ...
# 12  [martial, arts, boxer, fu, kung, master, rocky...
# 13  [drug, mexico, mexican, pablo, cartels, spanis...
# 14  [missing, disappearance, police, search, years...
# 15  [politician, political, vote, candidate, winni...
# 16  [lebanese, beirut, lebanons, syrian, syria, le...
# 17  [elizabeth, queen, dianas, royal, princess, en...
# 18  [marijuana, smokers, california, hardcore, fac...
# 19  [russian, revolution, petersburg, turkish, rus...
#
#                                   Representative_Docs
# 0   [After experiencing tragic loss, woman must re...
# 1   [Eight years young man framed murder, up-and-c...
# 2   [John Mulaney kid pals tackle existential topi...
# 3   [Degrassi's next generation high-tech newbies ...
# 4   [1979, single bohemian mom Dorothea, hoping he...
# 5   [After falling wormhole, space-dwelling teen m...
# 6   [Madagascar goes wild holiday spirit set Valen...
# 7   [competition show, contestants try earn $1 mil...
# 8   [When two evil entities kidnap princess plot b...
# 9   [female food blogger hired personal chef young...
# 10  [During World War II, British forces launch at...
# 11  [troubled doctor sets save life miracle worker...
# 12  [Martial arts master Ip springs action son's s...
# 13  [true story Colombia's infamously violent powe...
# 14  [Multiple women report husbands missing appear...
# 15  [Amid local election two rivals vying win mean...
# 16  [Abducted Lebanese Civil War 50s, Ramez finall...
# 17  [This drama follows political rivalries romanc...
# 18  [Humboldt County, California, big business leg...
# 19  [Starting 1881, film describes personal battle...

# %%
def generate_topic_name(list_of_words):

    llm = CTransformers(model='models\llama-2-7b-chat.ggmlv3.q8_0.bin',
                        model_type='llama',
                        config={'max_new_tokens': 256,
                                'temperature': 0.01})

    words = ', '.join([i for i in list_of_words])

    template = """
Given the following words that describe a genre of Netflix shows\films, return a one to two word name for the genre. Your response
should be one to two words with no other text:\n\"{words}\"
    """

    prompt = PromptTemplate(input_variables = ['words'], template=template)

    response = llm(prompt.format(words=words))

    return response

# %%
topic_names = []
all_topics = topic_model.get_topics()
for i in range(len(all_topics) - 1):
    list_of_words = []
    for word in all_topics[i]:
        list_of_words.append(word[0])
    topic_names.append(generate_topic_name(list_of_words))

# %%
all_topics[14]
# Out:
# [('contestants', 0.08927503220670463),
#  ('competition', 0.07348370732356461),
#  ('prize', 0.06710982451482556),
#  ('compete', 0.06584896015661276),
#  ('show', 0.06096761344217699),
#  ('for', 0.056810949391311934),
#  ('this', 0.05540364481809931),
#  ('in', 0.052369597782706105),
#  ('artists', 0.051267988150305796),
#  ('win', 0.04701476240106029)]

# %%
topic_names[14]
# Out:
# '\nThe genre is: Reality TV'
