# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset("hugginglearners/netflix-shows", split="train")
df = pd.DataFrame(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                                  None           None
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                               None           None
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
# Create bucket queue from the genres used in 'listed_in'
genre_lists = df['listed_in'].str.split(", ")
all_genres = set()
for genres in genre_lists:
    all_genres.update(genres)
bucket_queue = {genre: [] for genre in all_genres}

# %%
bucket_queue
# Out:
# {'Anime Series': [],
#  'Independent Movies': [],
#  'TV Thrillers': [],
#  'Korean TV Shows': [],
#  'LGBTQ Movies': [],
#  'Spanish-Language TV Shows': [],
#  'International TV Shows': [],
#  'Children & Family Movies': [],
#  'Classic Movies': [],
#  'Docuseries': [],
#  'Thrillers': [],
#  'Anime Features': [],
#  'Romantic Movies': [],
#  'TV Shows': [],
#  'Horror Movies': [],
#  'TV Comedies': [],
#  'TV Action & Adventure': [],
#  'Comedies': [],
#  'Action & Adventure': [],
#  'Faith & Spirituality': [],
#  'Reality TV': [],
#  'Classic & Cult TV': [],
#  'International Movies': [],
#  'TV Sci-Fi & Fantasy': [],
#  'Stand-Up Comedy & Talk Shows': [],
#  'TV Mysteries': [],
#  'Documentaries': [],
#  'Teen TV Shows': [],
#  "Kids' TV": [],
#  'Science & Nature TV': [],
#  'British TV Shows': [],
#  'Music & Musicals': [],
#  'Romantic TV Shows': [],
#  'Cult Movies': [],
#  'TV Horror': [],
#  'TV Dramas': [],
#  'Crime TV Shows': [],
#  'Sports Movies': [],
#  'Movies': [],
#  'Stand-Up Comedy': [],
#  'Dramas': [],
#  'Sci-Fi & Fantasy': []}

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained GPT-2 model and tokenizer
model_name = "gpt2-medium"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Define genre descriptions
genres = list(bucket_queue.keys())

# Generate and store descriptions for each genre
genre_descriptions = {}
for genre in genres:
    prompt = f"The genre is {genre}. Describe a typical {genre} TV show: "
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # Generate descriptions using the model
    max_length = 50  # Maximum length of the generated description
    num_descriptions = 3  # Number of descriptions to generate for each genre
    generated_descriptions = []
    for _ in range(num_descriptions):
        output = model.generate(input_ids, max_length=max_length, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
        generated_description = tokenizer.decode(output[0], skip_special_tokens=True)
        generated_descriptions.append(generated_description)

    genre_descriptions[genre] = generated_descriptions

# Print generated description for the genres
for genre, descriptions in genre_descriptions.items():
    print(f"Genre: {genre}")
    for i, description in enumerate(descriptions, start=1):
        print(f"Description {i}: {description}")
    print("\n")
# Out:
# Genre: Anime Series
# Description 1: The genre is Anime Series. Describe a typical Anime Series TV show:  A story about a boy who is a member of a group of heroes who fight evil.  The show is usually about a boy who is a member of a
# Description 2: The genre is Anime Series. Describe a typical Anime Series TV show:  A story about a boy who is a member of a group of heroes who fight evil.  The show is usually about a boy who is a member of a
# Description 3: The genre is Anime Series. Describe a typical Anime Series TV show:  A story about a boy who is a member of a group of heroes who fight evil.  The show is usually about a boy who is a member of a
V show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually a comedy, but can also be
# Description 2: The genre is Docuseries. Describe a typical Docuseries TV show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually a comedy, but can also be
# Description 3: The genre is Docuseries. Describe a typical Docuseries TV show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually a comedy, but can also be
#
#
# Genre: Thrillers
# Description 1: The genre is Thrillers. Describe a typical Thrillers TV show:  "A group of friends are having a party and they decide to go out for a drink. They decide to go out for a drink and they decide to
# Description 2: The genre is Thrillers. Describe a typical Thrillers TV show:  "A group of friends are having a party and they decide to go out for a drink. They decide to go out for a drink and they decide to
# Description 3: The genre is Thrillers. Describe a typical Thrillers TV show:  "A group of friends are having a party and they decide to go out for a drink. They decide to go out for a drink and they decide to
#
#
# Genre: Anime Features
# Description 1: The genre is Anime Features. Describe a typical Anime Features TV show:  "A show that is based on a popular anime series, but with a twist. The twist is that the characters are actually real people, and the show is based
# Description 2: The genre is Anime Features. Describe a typical Anime Features TV show:  "A show that is based on a popular anime series, but with a twist. The twist is that the characters are actually real people, and the show is based
# Description 3: The genre is Anime Features. Describe a typical Anime Features TV show:  "A show that is based on a popular anime series, but with a twist. The twist is that the characters are actually real people, and the show is based
#
#
# Genre: Romantic Movies
# Description 1: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  A romantic comedy, a romantic drama, a romantic comedy, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a
# Description 2: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  A romantic comedy, a romantic drama, a romantic comedy, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a
# Description 3: The genre is Romantic Movies. Describe a typical Romantic Movies TV show:  A romantic comedy, a romantic drama, a romantic comedy, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a romantic drama, a
#
#
# Genre: TV Shows
# Description 1: The genre is TV Shows. Describe a typical TV Shows TV show:  A TV show is a series of episodes that are usually broadcast on a regular basis.  The show is usually about a character or a group of characters.
# Description 2: The genre is TV Shows. Describe a typical TV Shows TV show:  A TV show is a series of episodes that are usually broadcast on a regular basis.  The show is usually about a character or a group of characters.
# Description 3: The genre is TV Shows. Describe a typical TV Shows TV show:  A TV show is a series of episodes that are usually broadcast on a regular basis.  The show is usually about a character or a group of characters.
#
#
# Genre: Horror Movies
# Description 1: The genre is Horror Movies. Describe a typical Horror Movies TV show:  A show that is about a group of people who are trapped in a house and have to fight to escape.  The show is usually about a group of people
# Description 2: The genre is Horror Movies. Describe a typical Horror Movies TV show:  A show that is about a group of people who are trapped in a house and have to fight to escape.  The show is usually about a group of people
# Description 3: The genre is Horror Movies. Describe a typical Horror Movies TV show:  A show that is about a group of people who are trapped in a house and have to fight to escape.  The show is usually about a group of people
#
#
# Genre: TV Comedies
# Description 1: The genre is TV Comedies. Describe a typical TV Comedies TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but can also be
# Description 2: The genre is TV Comedies. Describe a typical TV Comedies TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but can also be
# Description 3: The genre is TV Comedies. Describe a typical TV Comedies TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but can also be
#
#
# Genre: TV Action & Adventure
# Description 1: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually set in a dystopian future
# Description 2: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually set in a dystopian future
# Description 3: The genre is TV Action & Adventure. Describe a typical TV Action & Adventure TV show:  A show that follows a group of people who are trying to escape from a dangerous situation.  The show is usually set in a dystopian future
#
#
# Genre: Comedies
# Description 1: The genre is Comedies. Describe a typical Comedies TV show:  A comedy show is a show that is funny, but not too funny.  It is not a show that is too serious, but not too serious.
# Description 2: The genre is Comedies. Describe a typical Comedies TV show:  A comedy show is a show that is funny, but not too funny.  It is not a show that is too serious, but not too serious.
# Description 3: The genre is Comedies. Describe a typical Comedies TV show:  A comedy show is a show that is funny, but not too funny.  It is not a show that is too serious, but not too serious.
#
#
# Genre: Action & Adventure
# Description 1: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  A character is kidnapped by a mysterious organization, and must fight to save his life.  The show is usually set in a futuristic setting, with a
# Description 2: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  A character is kidnapped by a mysterious organization, and must fight to save his life.  The show is usually set in a futuristic setting, with a
# Description 3: The genre is Action & Adventure. Describe a typical Action & Adventure TV show:  A character is kidnapped by a mysterious organization, and must fight to save his life.  The show is usually set in a futuristic setting, with a
#
#
# Genre: Faith & Spirituality
# Description 1: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show:  "A show that is about faith and spirituality, but also about the world around us."  What is the most common theme of Faith &
# Description 2: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show:  "A show that is about faith and spirituality, but also about the world around us."  What is the most common theme of Faith &
# Description 3: The genre is Faith & Spirituality. Describe a typical Faith & Spirituality TV show:  "A show that is about faith and spirituality, but also about the world around us."  What is the most common theme of Faith &
#
#
# Genre: Reality TV
# Description 1: The genre is Reality TV. Describe a typical Reality TV TV show:  "A show where a celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the
# Description 2: The genre is Reality TV. Describe a typical Reality TV TV show:  "A show where a celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the
# Description 3: The genre is Reality TV. Describe a typical Reality TV TV show:  "A show where a celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the celebrity is a celebrity, and the
#
#
# Genre: Classic & Cult TV
# Description 1: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show:  A Classic TV show is a show that is not a continuation of a previous series.  It is a show that is not a continuation of
# Description 2: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show:  A Classic TV show is a show that is not a continuation of a previous series.  It is a show that is not a continuation of
# Description 3: The genre is Classic & Cult TV. Describe a typical Classic & Cult TV TV show:  A Classic TV show is a show that is not a continuation of a previous series.  It is a show that is not a continuation of
#
#
# Genre: International Movies
# Description 1: The genre is International Movies. Describe a typical International Movies TV show:  "A show that is about a group of people who are trying to make it in the world. They are trying to make it in the world by doing what they
# Description 2: The genre is International Movies. Describe a typical International Movies TV show:  "A show that is about a group of people who are trying to make it in the world. They are trying to make it in the world by doing what they
# Description 3: The genre is International Movies. Describe a typical International Movies TV show:  "A show that is about a group of people who are trying to make it in the world. They are trying to make it in the world by doing what they
#
#
# Genre: TV Sci-Fi & Fantasy
# Description 1: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  A TV Sci-Fi & Fantasy show is a show that is set in a world where the main characters are aliens, or
# Description 2: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  A TV Sci-Fi & Fantasy show is a show that is set in a world where the main characters are aliens, or
# Description 3: The genre is TV Sci-Fi & Fantasy. Describe a typical TV Sci-Fi & Fantasy TV show:  A TV Sci-Fi & Fantasy show is a show that is set in a world where the main characters are aliens, or
#
#
# Genre: Stand-Up Comedy & Talk Shows
# Description 1: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:  A show that is funny, entertaining, and informative.  It is usually a comedy show that is hosted by
# Description 2: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:  A show that is funny, entertaining, and informative.  It is usually a comedy show that is hosted by
# Description 3: The genre is Stand-Up Comedy & Talk Shows. Describe a typical Stand-Up Comedy & Talk Shows TV show:  A show that is funny, entertaining, and informative.  It is usually a comedy show that is hosted by
#
#
# Genre: TV Mysteries
# Description 1: The genre is TV Mysteries. Describe a typical TV Mysteries TV show:  A mystery is a story that involves a character who is not a regular person, but who is a mystery.  The show is usually about a character who is
# Description 2: The genre is TV Mysteries. Describe a typical TV Mysteries TV show:
The genre is Romantic TV Shows. Describe a typical Romantic TV Shows TV show:  A romantic comedy, drama, or comedy.
# A romantic comedy, drama, or comedy. A romantic comedy, drama, or comedy. A romantic comedy
#
#
# Genre: Cult Movies
# Description 1: The genre is Cult Movies. Describe a typical Cult Movies TV show:  "A cult movie is a movie that is made by a group of people who believe that they are the only ones who can make a movie that is good. They
# Description 2: The genre is Cult Movies. Describe a typical Cult Movies TV show:  "A cult movie is a movie that is made by a group of people who believe that they are the only ones who can make a movie that is good. They
# Description 3: The genre is Cult Movies. Describe a typical Cult Movies TV show:  "A cult movie is a movie that is made by a group of people who believe that they are the only ones who can make a movie that is good. They
#
#
# Genre: TV Horror
# Description 1: The genre is TV Horror. Describe a typical TV Horror TV show:  A story that is set in a fictional world, but is not based on real life.  A story that is set in a fictional world, but is not
# Description 2: The genre is TV Horror. Describe a typical TV Horror TV show:  A story that is set in a fictional world, but is not based on real life.  A story that is set in a fictional world, but is not
# Description 3: The genre is TV Horror. Describe a typical TV Horror TV show:  A story that is set in a fictional world, but is not based on real life.  A story that is set in a fictional world, but is not
#
#
# Genre: TV Dramas
# Description 1: The genre is TV Dramas. Describe a typical TV Dramas TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but there are exceptions
# Description 2: The genre is TV Dramas. Describe a typical TV Dramas TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but there are exceptions
# Description 3: The genre is TV Dramas. Describe a typical TV Dramas TV show:  A TV show is a series of episodes that are usually about a single character.  The show is usually about a single character, but there are exceptions
#
#
# Genre: Crime TV Shows
# Description 1: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  A crime drama, a crime thriller, a crime comedy, a crime drama, a crime thriller, a crime comedy, a crime drama, a crime drama
# Description 2: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  A crime drama, a crime thriller, a crime comedy, a crime drama, a crime thriller, a crime comedy, a crime drama, a crime drama
# Description 3: The genre is Crime TV Shows. Describe a typical Crime TV Shows TV show:  A crime drama, a crime thriller, a crime comedy, a crime drama, a crime thriller, a crime comedy, a crime drama, a crime drama
#
#
# Genre: Sports Movies
# Description 1: The genre is Sports Movies. Describe a typical Sports Movies TV show:  A sports movie is a movie that is made for sports fans.  It is usually a sports movie that is made for sports fans.  It is usually
# Description 2: The genre is Sports Movies. Describe a typical Sports Movies TV show:  A sports movie is a movie that is made for sports fans.  It is usually a sports movie that is made for sports fans.  It is usually
# Description 3: The genre is Sports Movies. Describe a typical Sports Movies TV show:  A sports movie is a movie that is made for sports fans.  It is usually a sports movie that is made for sports fans.  It is usually
#
#
# Genre: Movies
# Description 1: The genre is Movies. Describe a typical Movies TV show:  A show that is about a group of people who are trying to make it in the world.  A show that is about a group of people who are trying to make
# Description 2: The genre is Movies. Describe a typical Movies TV show:  A show that is about a group of people who are trying to make it in the world.  A show that is about a group of people who are trying to make
# Description 3: The genre is Movies. Describe a typical Movies TV show:  A show that is about a group of people who are trying to make it in the world.  A show that is about a group of people who are trying to make
#
#
# Genre: Stand-Up Comedy
# Description 1: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show:  "A comedy show where the characters are all stand-up comedians. The characters are usually comedians, but sometimes they are actors, actors, actors
# Description 2: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show:  "A comedy show where the characters are all stand-up comedians. The characters are usually comedians, but sometimes they are actors, actors, actors
# Description 3: The genre is Stand-Up Comedy. Describe a typical Stand-Up Comedy TV show:  "A comedy show where the characters are all stand-up comedians. The characters are usually comedians, but sometimes they are actors, actors, actors
#
#
# Genre: Dramas
# Description 1: The genre is Dramas. Describe a typical Dramas TV show:  A drama is a story about a family, a group of people, or a group of people in a group.  A drama is usually about a family,
# Description 2: The genre is Dramas. Describe a typical Dramas TV show:  A drama is a story about a family, a group of people, or a group of people in a group.  A drama is usually about a family,
# Description 3: The genre is Dramas. Describe a typical Dramas TV show:  A drama is a story about a family, a group of people, or a group of people in a group.  A drama is usually about a family,
#
#
# Genre: Sci-Fi & Fantasy
# Description 1: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show:  What is the genre?  What is the story?  What is the setting?  What is the setting's setting
# Description 2: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show:  What is the genre?  What is the story?  What is the setting?  What is the setting's setting
# Description 3: The genre is Sci-Fi & Fantasy. Describe a typical Sci-Fi & Fantasy TV show:  What is the genre?  What is the story?  What is the setting?  What is the setting's setting

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from fuzzywuzzy import fuzz

# Function to find the most similar genre for a given description
def find_genre(description):
    max_similarity = 0
    most_similar_genre = None

    for genre, descriptions in genre_descriptions.items():
        for gen_desc in descriptions:
            similarity = fuzz.token_sort_ratio(description.lower(), gen_desc.lower())
            if similarity > max_similarity:
                max_similarity = similarity
                most_similar_genre = genre

    return most_similar_genre

# Iterate through the dataset to label rows with corresponding buckets
df_small = df.head(500)
for index, row in df_small.iterrows():
    description = row['description']
    genre = find_genre(description)
    df_small.at[index, 'bucket'] = genre

# %%
df_small
# Out:
#     show_id     type                  title           director  \
# 0        s1    Movie   Dick Johnson Is Dead    Kirsten Johnson
# 1        s2  TV Show          Blood & Water               None
# 2        s3  TV Show              Ganglands    Julien Leclercq
# 3        s4  TV Show  Jailbirds New Orleans               None
# 4        s5  TV Show           Kota Factory               None
# ..      ...      ...                    ...                ...
# 495    s496    Movie              Awon Boyz  Tolulope Itegboje
# 496    s497    Movie         Brick Mansions  Camille Delamarre
# 497    s498  TV Show             Cat People               None
# 498    s499    Movie                  Clash       Pascal Atuma
# 499    s500  TV Show                   Dogs               None
#
#                                                   cast  \
# 0                                                 None
# 1    Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2    Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 None
# 4    Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ..                                                 ...
# 495                                               None
# 496  Paul Walker, David Belle, RZA, Gouchy Boy, Cat...
# 497                                               None
# 498  Omoni Oboli, Brian Hooks, Stephanie Linus, Mer...
# 499                                               None
#
#                                   country          date_added  release_year  \
# 0                           United States  September 25, 2021          2020
# 1                            South Africa  September 24, 2021          2021
# 2                                    None  September 24, 2021          2021
# 3                                    None  September 24, 2021          2021
# 4                                   India  September 24, 2021          2021
# ..                                    ...                 ...           ...
# 495                                  None        July 7, 2021          2019
# 496  France, Canada, United States, Spain        July 7, 2021          2014
# 497                                  None        July 7, 2021          2021
# 498                                  None        July 7, 2021          2020
# 499                         United States        July 7, 2021          2021
#
#     rating   duration                                          listed_in  \
# 0    PG-13     90 min                                      Documentaries
# 1    TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2    TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3    TV-MA   1 Season                             Docuseries, Reality TV
# 4    TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# ..     ...        ...                                                ...
# 495  TV-MA     38 min                Documentaries, International Movies
# 496  PG-13     90 min           Action & Adventure, International Movies
# 497  TV-14   1 Season                                         Docuseries
# 498  TV-MA     87 min                       Dramas, International Movies
# 499  TV-PG  2 Seasons                                         Docuseries
#
#                                            description               bucket
# 0    As her father nears the end of his life, filmm...     Music & Musicals
# 1    After crossing paths at a party, a Cape Town t...           Docuseries
# 2    To protect his family from a powerful drug lor...            Thrillers
# 3    Feuds, flirtations and toilet talk go down amo...  TV Sci-Fi & Fantasy
# 4    In a city of coaching centers known to train I...             Comedies
# ..                                                 ...                  ...
# 495  This documentary takes a close look at the liv...         LGBTQ Movies
# 496  An undercover police detective partners with a...         LGBTQ Movies
# 497  Cat people come in all shapes and sizes, but t...           Docuseries
# 498  When the patriarch of an emigrant Nigerian fam...               Dramas
# 499  These six intimate stories explore the abiding...  TV Sci-Fi & Fantasy
#
# [500 rows x 13 columns]

# %%
from collections import defaultdict

# Initialize counters for correct and total predictions for each bucket
correct_predictions = defaultdict(int)
total_predictions = defaultdict(int)

# Loop through each row in the dataset
for index, row in df_small.iterrows():
    predicted_genre = row['bucket']  # Predicted genre
    listed_in = row['listed_in'].split(", ")  # Actual genres listed in the 'listed_in' column

    # Check if the predicted genre matches any of the actual genres
    for genre in listed_in:
        total_predictions[genre] += 1  # Increment total predictions for the actual genre
        if predicted_genre == genre:
            correct_predictions[genre] += 1  # Increment correct predictions if the predicted genre matches the actual genre

# Calculate accuracy for each bucket
accuracy_per_bucket = {}
for genre, total in total_predictions.items():
    if total > 0:
        accuracy_per_bucket[genre] = correct_predictions[genre] / total

# Overall accuracy
overall_accuracy = sum(correct_predictions.values()) / sum(total_predictions.values())

print("Accuracy per Bucket:")
for genre, accuracy in accuracy_per_bucket.items():
    print(f"{genre}: {accuracy:.2f}")

print(f"\nOverall Accuracy: {overall_accuracy:.2f}")
# Out:
# Accuracy per Bucket:
# Documentaries: 0.00
# International TV Shows: 0.00
# TV Dramas: 0.00
# TV Mysteries: 0.00
# Crime TV Shows: 0.00
# TV Action & Adventure: 0.00
# Docuseries: 0.24
# Reality TV: 0.00
# Romantic TV Shows: 0.00
# TV Comedies: 0.00
# TV Horror: 0.00
# Children & Family Movies: 0.00
# Dramas: 0.04
# Independent Movies: 0.00
# International Movies: 0.00
# British TV Shows: 0.00
# Comedies: 0.04
# Spanish-Language TV Shows: 0.00
# Thrillers: 0.19
# Romantic Movies: 0.00
# Music & Musicals: 0.24
# Horror Movies: 0.00
# Sci-Fi & Fantasy: 0.00
# TV Thrillers: 0.00
# Kids' TV: 0.00
# Action & Adventure: 0.00
# TV Sci-Fi & Fantasy: 0.00
# Classic Movies: 0.00
# Anime Features: 0.00
# Sports Movies: 0.00
# Anime Series: 0.17
# Korean TV Shows: 0.00
# Science & Nature TV: 0.00
# Teen TV Shows: 0.00
# Cult Movies: 0.00
# TV Shows: 0.00
# Faith & Spirituality: 0.00
# LGBTQ Movies: 0.20
# Stand-Up Comedy: 0.00
# Movies: 0.50
# Stand-Up Comedy & Talk Shows: 0.00
# Classic & Cult TV: 0.00
#
# Overall Accuracy: 0.03
